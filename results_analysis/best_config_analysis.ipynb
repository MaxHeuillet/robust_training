# %%
import pickle
import omegaconf
import warnings
import pickle
import numpy as np
import yaml
warnings.filterwarnings("ignore", category=DeprecationWarning)

project_name = 'full_fine_tuning_50epochs_final3'

datas=( 'uc-merced-land-use-dataset', 'stanford_cars', 'caltech101', 'fgvc-aircraft-2013b', 'flowers-102', 'oxford-iiit-pet' ) #'dtd',

losses=( 'TRADES_v2', 'CLASSIC_AT' ) #  

backbones=(

  # SCIENTIFIC HYPOTHESES BACKBONES
  'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K',
  'CLIP-convnext_base_w-laion2B-s13B-b82K',
  'deit_small_patch16_224.fb_in1k',
  'robust_resnet50',
  'vit_base_patch16_224.mae',
  'vit_small_patch16_224.augreg_in21k',
  'convnext_base.fb_in1k',
  'resnet50.a1_in1k',
  'robust_vit_base_patch16_224',
  'vit_base_patch16_224.sam_in1k',
  'vit_small_patch16_224.dino',
  'convnext_base.fb_in22k',
  'robust_convnext_base',
  'vit_base_patch16_224.augreg_in1k',
  'vit_base_patch16_224.augreg_in21k',
#   'vit_base_patch16_224.dino',
  'vit_base_patch16_clip_224.laion2b',
  'convnext_tiny.fb_in1k',
  'robust_convnext_tiny',
  'robust_deit_small_patch16_224',
  'vit_base_patch16_224.dino',
  'vit_small_patch16_224.augreg_in1k',
  'convnext_tiny.fb_in22k',

  # PERFORMANCE BACKBONES
  'vit_base_patch16_clip_224.laion2b_ft_in1k',
  'vit_base_patch16_224.augreg_in21k_ft_in1k',
  'vit_small_patch16_224.augreg_in21k_ft_in1k',
  'eva02_base_patch14_224.mim_in22k',
  'eva02_tiny_patch14_224.mim_in22k',
  'swin_base_patch4_window7_224.ms_in22k_ft_in1k',
  'swin_tiny_patch4_window7_224.ms_in1k',
  'convnext_base.clip_laion2b_augreg_ft_in12k_in1k',
  'convnext_base.fb_in22k_ft_in1k',
  'convnext_tiny.fb_in22k_ft_in1k'
)


final_data = []

for backbone in backbones:
    for loss in losses:
        for data in datas:

            try:
                name ='{}_{}_{}'.format(backbone, data, loss)
                print( '../configs/HPO_results/{}/{}.yaml'.format(project_name, name) )
                with open('../configs/HPO_results/{}/{}.yaml'.format(project_name, name), 'r') as f:
                    result =  yaml.safe_load(f)
                                    # result = saved_data[name]["statistics"]

                print(result)

            except:
                result = {}
                print('pass')
                # result = {'clean_acc': None, 'Linf_acc': None, 'L2_acc': None, 'L1_acc': None, 'common_acc': None}

            # result['backbone'] = backbone
            # result['dataset'] = data
            # result['loss_function'] = loss  
            final_data.append(result)
# Out:
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_uc-merced-land-use-dataset_TRADES_v2.yaml
# {'dataset': 'uc-merced-land-use-dataset', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00022637689662222718, 'lr2': 0.001246190805485586, 'weight_decay1': 0.0010460822384971702, 'weight_decay2': 7.16854697686896e-05, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_uc-merced-land-use-dataset_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_stanford_cars_TRADES_v2.yaml
# {'dataset': 'stanford_cars', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0001793480721178975, 'lr2': 0.005878824056644075, 'weight_decay1': 0.0032029975700290426, 'weight_decay2': 0.00378814552109712, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_stanford_cars_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_caltech101_TRADES_v2.yaml
# {'dataset': 'caltech101', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0001793480721178975, 'lr2': 0.005878824056644075, 'weight_decay1': 0.0032029975700290426, 'weight_decay2': 0.00378814552109712, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_caltech101_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_fgvc-aircraft-2013b_TRADES_v2.yaml
# {'dataset': 'fgvc-aircraft-2013b', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0001793480721178975, 'lr2': 0.005878824056644075, 'weight_decay1': 0.0032029975700290426, 'weight_decay2': 0.00378814552109712, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_fgvc-aircraft-2013b_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_flowers-102_TRADES_v2.yaml
# {'dataset': 'flowers-102', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00011186451269342267, 'lr2': 0.010015892466752692, 'weight_decay1': 6.728237446164208e-05, 'weight_decay2': 1.6893426773335825e-06, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_flowers-102_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_oxford-iiit-pet_TRADES_v2.yaml
# {'dataset': 'oxford-iiit-pet', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00012365164457104434, 'lr2': 1.7257298262927544e-05, 'weight_decay1': 0.00048096354537337677, 'weight_decay2': 0.0002356470857433856, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_oxford-iiit-pet_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# {'dataset': 'uc-merced-land-use-dataset', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.00030738911648555827, 'lr2': 0.000263773794245883, 'weight_decay1': 1.7006667818377532e-06, 'weight_decay2': 0.00033619132859648293, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_uc-merced-land-use-dataset_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_stanford_cars_CLASSIC_AT.yaml
# {'dataset': 'stanford_cars', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 3.05755179664374e-05, 'lr2': 1.5073271237666678e-05, 'weight_decay1': 2.6913892686855095e-06, 'weight_decay2': 7.995347689531275e-06, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_stanford_cars_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_caltech101_CLASSIC_AT.yaml
# {'dataset': 'caltech101', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.000385765077377004, 'lr2': 0.0003561582138458752, 'weight_decay1': 0.00047751184301655973, 'weight_decay2': 0.0055227614309091245, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_caltech101_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# {'dataset': 'fgvc-aircraft-2013b', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.00012365164457104434, 'lr2': 1.7257298262927544e-05, 'weight_decay1': 0.00048096354537337677, 'weight_decay2': 0.0002356470857433856, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_fgvc-aircraft-2013b_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_flowers-102_CLASSIC_AT.yaml
# {'dataset': 'flowers-102', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.00016475678324414964, 'lr2': 0.011389266983516912, 'weight_decay1': 0.0003218753941868195, 'weight_decay2': 0.000698845665057193, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_flowers-102_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_oxford-iiit-pet_CLASSIC_AT.yaml
# {'dataset': 'oxford-iiit-pet', 'backbone': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.00011702754074940317, 'lr2': 2.117853229368987e-05, 'weight_decay1': 5.1817363812507974e-05, 'weight_decay2': 2.7294494536984695e-06, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion_aesthetic-s13B-b82K_oxford-iiit-pet_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_uc-merced-land-use-dataset_TRADES_v2.yaml
# {'dataset': 'uc-merced-land-use-dataset', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00014494124526542618, 'lr2': 7.371671104681936e-05, 'weight_decay1': 1.1664398713186462e-06, 'weight_decay2': 3.93220580224794e-05, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_uc-merced-land-use-dataset_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_stanford_cars_TRADES_v2.yaml
# {'dataset': 'stanford_cars', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0001793480721178975, 'lr2': 0.005878824056644075, 'weight_decay1': 0.0032029975700290426, 'weight_decay2': 0.00378814552109712, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_stanford_cars_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_caltech101_TRADES_v2.yaml
# {'dataset': 'caltech101', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0001793480721178975, 'lr2': 0.005878824056644075, 'weight_decay1': 0.0032029975700290426, 'weight_decay2': 0.00378814552109712, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_caltech101_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_fgvc-aircraft-2013b_TRADES_v2.yaml
# {'dataset': 'fgvc-aircraft-2013b', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0001793480721178975, 'lr2': 0.005878824056644075, 'weight_decay1': 0.0032029975700290426, 'weight_decay2': 0.00378814552109712, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_fgvc-aircraft-2013b_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_flowers-102_TRADES_v2.yaml
# {'dataset': 'flowers-102', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0001793480721178975, 'lr2': 0.005878824056644075, 'weight_decay1': 0.0032029975700290426, 'weight_decay2': 0.00378814552109712, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_flowers-102_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_oxford-iiit-pet_TRADES_v2.yaml
# {'dataset': 'oxford-iiit-pet', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00012365164457104434, 'lr2': 1.7257298262927544e-05, 'weight_decay1': 0.00048096354537337677, 'weight_decay2': 0.0002356470857433856, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_oxford-iiit-pet_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# {'dataset': 'uc-merced-land-use-dataset', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.00014494124526542618, 'lr2': 7.371671104681936e-05, 'weight_decay1': 1.1664398713186462e-06, 'weight_decay2': 3.93220580224794e-05, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_uc-merced-land-use-dataset_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_stanford_cars_CLASSIC_AT.yaml
# {'dataset': 'stanford_cars', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 4.890598759712438e-05, 'lr2': 3.5362503098265404e-05, 'weight_decay1': 0.005375041876450287, 'weight_decay2': 0.0006127349401923009, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_stanford_cars_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_caltech101_CLASSIC_AT.yaml
# {'dataset': 'caltech101', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.000385765077377004, 'lr2': 0.0003561582138458752, 'weight_decay1': 0.00047751184301655973, 'weight_decay2': 0.0055227614309091245, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_caltech101_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# {'dataset': 'fgvc-aircraft-2013b', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 4.890598759712438e-05, 'lr2': 3.5362503098265404e-05, 'weight_decay1': 0.005375041876450287, 'weight_decay2': 0.0006127349401923009, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_fgvc-aircraft-2013b_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_flowers-102_CLASSIC_AT.yaml
# {'dataset': 'flowers-102', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.00035588620665567914, 'lr2': 0.0006824844006418367, 'weight_decay1': 0.000876856394490817, 'weight_decay2': 0.0043505864544563285, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_flowers-102_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/CLIP-convnext_base_w-laion2B-s13B-b82K_oxford-iiit-pet_CLASSIC_AT.yaml
# {'dataset': 'oxford-iiit-pet', 'backbone': 'CLIP-convnext_base_w-laion2B-s13B-b82K', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.000385765077377004, 'lr2': 0.0003561582138458752, 'weight_decay1': 0.00047751184301655973, 'weight_decay2': 0.0055227614309091245, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'CLIP-convnext_base_w-laion2B-s13B-b82K_oxford-iiit-pet_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_uc-merced-land-use-dataset_TRADES_v2.yaml
# {'dataset': 'uc-merced-land-use-dataset', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0005398028217148949, 'lr2': 0.0006067070759251295, 'weight_decay1': 0.00027307663690600463, 'weight_decay2': 9.569676503068063e-06, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_uc-merced-land-use-dataset_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_stanford_cars_TRADES_v2.yaml
# {'dataset': 'stanford_cars', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0005042680763563854, 'lr2': 0.009926359489660282, 'weight_decay1': 1.3547002161483293e-06, 'weight_decay2': 8.47989451854884e-05, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_stanford_cars_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_caltech101_TRADES_v2.yaml
# {'dataset': 'caltech101', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00027198143746106723, 'lr2': 0.0017402081259278966, 'weight_decay1': 0.008197784029366871, 'weight_decay2': 7.513870647601067e-05, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_caltech101_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_fgvc-aircraft-2013b_TRADES_v2.yaml
# {'dataset': 'fgvc-aircraft-2013b', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00015906252895766073, 'lr2': 0.003157275985300187, 'weight_decay1': 0.0003883962400562118, 'weight_decay2': 1.9377623573934265e-06, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_fgvc-aircraft-2013b_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_flowers-102_TRADES_v2.yaml
# {'dataset': 'flowers-102', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00031168976977779443, 'lr2': 0.012809397604718, 'weight_decay1': 3.0132736002416525e-06, 'weight_decay2': 5.158822036620095e-06, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_flowers-102_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_oxford-iiit-pet_TRADES_v2.yaml
# {'dataset': 'oxford-iiit-pet', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0005439180921646733, 'lr2': 0.00033874260973092255, 'weight_decay1': 7.57105080236878e-05, 'weight_decay2': 0.00827815238590798, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_oxford-iiit-pet_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# {'dataset': 'uc-merced-land-use-dataset', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.0007089970107184327, 'lr2': 0.002720004012262741, 'weight_decay1': 1.6883487519453224e-06, 'weight_decay2': 1.6245003268453136e-05, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_uc-merced-land-use-dataset_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_stanford_cars_CLASSIC_AT.yaml
# {'dataset': 'stanford_cars', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.0006411100645500921, 'lr2': 0.0003174967855298645, 'weight_decay1': 0.007968932296063852, 'weight_decay2': 4.698218090624928e-06, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_stanford_cars_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_caltech101_CLASSIC_AT.yaml
# {'dataset': 'caltech101', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.00019675092732811177, 'lr2': 0.0026900947323446386, 'weight_decay1': 0.0004011668392282042, 'weight_decay2': 0.002422246834069651, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_caltech101_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# {'dataset': 'fgvc-aircraft-2013b', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.0006176591919559785, 'lr2': 0.002022062341326675, 'weight_decay1': 6.3953845708687885e-06, 'weight_decay2': 0.0007622047419351692, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_fgvc-aircraft-2013b_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_flowers-102_CLASSIC_AT.yaml
# {'dataset': 'flowers-102', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.0006742473247420364, 'lr2': 0.0005281949792845911, 'weight_decay1': 0.005708357416333576, 'weight_decay2': 0.001298843859025954, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_flowers-102_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/deit_small_patch16_224.fb_in1k_oxford-iiit-pet_CLASSIC_AT.yaml
# {'dataset': 'oxford-iiit-pet', 'backbone': 'deit_small_patch16_224.fb_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.0004962871582332243, 'lr2': 0.00017767452534135224, 'weight_decay1': 2.8519079061647192e-05, 'weight_decay2': 0.00033016212172498757, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'deit_small_patch16_224.fb_in1k_oxford-iiit-pet_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_uc-merced-land-use-dataset_TRADES_v2.yaml
# {'dataset': 'uc-merced-land-use-dataset', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00022876928659648665, 'lr2': 8.549974269902048e-05, 'weight_decay1': 7.1457246032359e-05, 'weight_decay2': 0.0008568191364121131, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_uc-merced-land-use-dataset_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_stanford_cars_TRADES_v2.yaml
# {'dataset': 'stanford_cars', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00022637689662222718, 'lr2': 0.001246190805485586, 'weight_decay1': 0.0010460822384971702, 'weight_decay2': 7.16854697686896e-05, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_stanford_cars_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_caltech101_TRADES_v2.yaml
# {'dataset': 'caltech101', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 4.998970805497902e-05, 'lr2': 0.0019180653780121934, 'weight_decay1': 0.009705405847299987, 'weight_decay2': 0.0018507187937083912, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_caltech101_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_fgvc-aircraft-2013b_TRADES_v2.yaml
# {'dataset': 'fgvc-aircraft-2013b', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00042345911090525004, 'lr2': 0.00026646511115885964, 'weight_decay1': 4.023686699039714e-06, 'weight_decay2': 0.0026661971014274844, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_fgvc-aircraft-2013b_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_flowers-102_TRADES_v2.yaml
# {'dataset': 'flowers-102', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0005798468061966809, 'lr2': 0.0008338976137672945, 'weight_decay1': 2.153462115501369e-05, 'weight_decay2': 1.0855521867612999e-06, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_flowers-102_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_oxford-iiit-pet_TRADES_v2.yaml
# {'dataset': 'oxford-iiit-pet', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 4.998970805497902e-05, 'lr2': 0.0019180653780121934, 'weight_decay1': 0.009705405847299987, 'weight_decay2': 0.0018507187937083912, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_oxford-iiit-pet_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# {'dataset': 'uc-merced-land-use-dataset', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.0001835234726195879, 'lr2': 0.0009329791582603169, 'weight_decay1': 0.0017585858192924542, 'weight_decay2': 0.0002814723699638867, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_uc-merced-land-use-dataset_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_stanford_cars_CLASSIC_AT.yaml
# {'dataset': 'stanford_cars', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.00022637689662222718, 'lr2': 0.001246190805485586, 'weight_decay1': 0.0010460822384971702, 'weight_decay2': 7.16854697686896e-05, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_stanford_cars_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_caltech101_CLASSIC_AT.yaml
# {'dataset': 'caltech101', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.00010745127075411959, 'lr2': 0.0018064875597039452, 'weight_decay1': 3.3862462111748364e-06, 'weight_decay2': 3.078581942280645e-05, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_caltech101_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# {'dataset': 'fgvc-aircraft-2013b', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.00042345911090525004, 'lr2': 0.00026646511115885964, 'weight_decay1': 4.023686699039714e-06, 'weight_decay2': 0.0026661971014274844, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_fgvc-aircraft-2013b_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_flowers-102_CLASSIC_AT.yaml
# {'dataset': 'flowers-102', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 9.3507277180641e-05, 'lr2': 0.003674599208195388, 'weight_decay1': 1.7413938646261666e-05, 'weight_decay2': 1.1774641906345048e-05, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_flowers-102_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/robust_resnet50_oxford-iiit-pet_CLASSIC_AT.yaml
# {'dataset': 'oxford-iiit-pet', 'backbone': 'robust_resnet50', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 3.818233125284081e-05, 'lr2': 0.0010925798251745034, 'weight_decay1': 1.540949276095007e-05, 'weight_decay2': 0.0027453885260328528, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'robust_resnet50_oxford-iiit-pet_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_base_patch16_224.mae_uc-merced-land-use-dataset_TRADES_v2.yaml
# {'dataset': 'uc-merced-land-use-dataset', 'backbone': 'vit_base_patch16_224.mae', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.00016305071356754347, 'lr2': 0.003018441584633846, 'weight_decay1': 2.5425721253289475e-05, 'weight_decay2': 1.9474517236575887e-05, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'vit_base_patch16_224.mae_uc-merced-land-use-dataset_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_base_patch16_224.mae_stanford_cars_TRADES_v2.yaml
# {'dataset': 'stanford_cars', 'backbone': 'vit_base_patch16_224.mae', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0001793480721178975, 'lr2': 0.005878824056644075, 'weight_decay1': 0.0032029975700290426, 'weight_decay2': 0.00378814552109712, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'vit_base_patch16_224.mae_stanford_cars_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_base_patch16_224.mae_caltech101_TRADES_v2.yaml
# {'dataset': 'caltech101', 'backbone': 'vit_base_patch16_224.mae', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0001793480721178975, 'lr2': 0.005878824056644075, 'weight_decay1': 0.0032029975700290426, 'weight_decay2': 0.00378814552109712, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'vit_base_patch16_224.mae_caltech101_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ...
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_base_patch16_224.augreg_in21k_ft_in1k_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_base_patch16_224.augreg_in21k_ft_in1k_stanford_cars_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_base_patch16_224.augreg_in21k_ft_in1k_caltech101_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_base_patch16_224.augreg_in21k_ft_in1k_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# {'dataset': 'fgvc-aircraft-2013b', 'backbone': 'vit_base_patch16_224.augreg_in21k_ft_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.0006742473247420364, 'lr2': 0.0005281949792845911, 'weight_decay1': 0.005708357416333576, 'weight_decay2': 0.001298843859025954, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'vit_base_patch16_224.augreg_in21k_ft_in1k_fgvc-aircraft-2013b_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_base_patch16_224.augreg_in21k_ft_in1k_flowers-102_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_base_patch16_224.augreg_in21k_ft_in1k_oxford-iiit-pet_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_uc-merced-land-use-dataset_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_stanford_cars_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_caltech101_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_fgvc-aircraft-2013b_TRADES_v2.yaml
# {'dataset': 'fgvc-aircraft-2013b', 'backbone': 'vit_small_patch16_224.augreg_in21k_ft_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'TRADES_v2', 'seed': 1, 'epochs': 50, 'lr1': 0.0006742473247420364, 'lr2': 0.0005281949792845911, 'weight_decay1': 0.005708357416333576, 'weight_decay2': 0.001298843859025954, 'scheduler': False, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'vit_small_patch16_224.augreg_in21k_ft_in1k_fgvc-aircraft-2013b_TRADES_v2', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_flowers-102_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_oxford-iiit-pet_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_stanford_cars_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_caltech101_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# {'dataset': 'fgvc-aircraft-2013b', 'backbone': 'vit_small_patch16_224.augreg_in21k_ft_in1k', 'ft_type': 'full_fine_tuning', 'loss_function': 'CLASSIC_AT', 'seed': 1, 'epochs': 50, 'lr1': 0.005506529897945982, 'lr2': 6.573686655138324e-05, 'weight_decay1': 0.0032543911150884836, 'weight_decay2': 1.2869165107815028e-06, 'scheduler': True, 'use_rs': False, 'epsilon': 0.015686275, 'step_size': 0.007843137, 'perturb_steps': 10, 'distance': 'Linf', 'beta': 1.0, 'project_name': 'full_fine_tuning_50epochs_final3', 'exp_id': 'vit_small_patch16_224.augreg_in21k_ft_in1k_fgvc-aircraft-2013b_CLASSIC_AT', 'statedicts_path': '~/scratch/state_dicts_share/', 'trained_statedicts_path': '~/scratch/trained_state_dicts/', 'datasets_path': '$SLURM_TMPDIR/data', 'configs_path': './configs', 'results_path': './results', 'hpo_path': '~/scratch/hpo_results/'}
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_flowers-102_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/vit_small_patch16_224.augreg_in21k_ft_in1k_oxford-iiit-pet_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_uc-merced-land-use-dataset_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_stanford_cars_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_caltech101_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_fgvc-aircraft-2013b_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_flowers-102_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_oxford-iiit-pet_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_stanford_cars_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_caltech101_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_flowers-102_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_base_patch14_224.mim_in22k_oxford-iiit-pet_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_uc-merced-land-use-dataset_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_stanford_cars_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_caltech101_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_fgvc-aircraft-2013b_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_flowers-102_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_oxford-iiit-pet_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_stanford_cars_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_caltech101_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_flowers-102_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/eva02_tiny_patch14_224.mim_in22k_oxford-iiit-pet_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_uc-merced-land-use-dataset_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_stanford_cars_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_caltech101_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_fgvc-aircraft-2013b_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_flowers-102_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_oxford-iiit-pet_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_stanford_cars_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_caltech101_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_flowers-102_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_base_patch4_window7_224.ms_in22k_ft_in1k_oxford-iiit-pet_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_uc-merced-land-use-dataset_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_stanford_cars_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_caltech101_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_fgvc-aircraft-2013b_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_flowers-102_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_oxford-iiit-pet_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_stanford_cars_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_caltech101_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_flowers-102_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/swin_tiny_patch4_window7_224.ms_in1k_oxford-iiit-pet_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_uc-merced-land-use-dataset_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_stanford_cars_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_caltech101_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_fgvc-aircraft-2013b_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_flowers-102_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_oxford-iiit-pet_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_stanford_cars_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_caltech101_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_flowers-102_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.clip_laion2b_augreg_ft_in12k_in1k_oxford-iiit-pet_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_uc-merced-land-use-dataset_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_stanford_cars_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_caltech101_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_fgvc-aircraft-2013b_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_flowers-102_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_oxford-iiit-pet_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_stanford_cars_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_caltech101_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_flowers-102_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_base.fb_in22k_ft_in1k_oxford-iiit-pet_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_uc-merced-land-use-dataset_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_stanford_cars_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_caltech101_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_fgvc-aircraft-2013b_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_flowers-102_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_oxford-iiit-pet_TRADES_v2.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_uc-merced-land-use-dataset_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_stanford_cars_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_caltech101_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_fgvc-aircraft-2013b_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_flowers-102_CLASSIC_AT.yaml
# pass
# ../configs/HPO_results/full_fine_tuning_50epochs_final3/convnext_tiny.fb_in22k_ft_in1k_oxford-iiit-pet_CLASSIC_AT.yaml
# pass

# %%
import pandas as pd
df = pd.DataFrame(final_data)
df.columns


wanted_cols = ['dataset', 'backbone', 'ft_type', 'loss_function', 
               'lr1', 'lr2', 'weight_decay1', 'weight_decay2', 'scheduler']

filtered_df = df[wanted_cols]

df_clean = df.dropna()
df_clean

# df_clean.to_csv("../figures/hpo_dataset.csv", index=False)
# Out:
#                         dataset  \
# 0    uc-merced-land-use-dataset
# 1                 stanford_cars
# 2                    caltech101
# 3           fgvc-aircraft-2013b
# 4                   flowers-102
# ..                          ...
# 273         fgvc-aircraft-2013b
# 279         fgvc-aircraft-2013b
# 285         fgvc-aircraft-2013b
# 291         fgvc-aircraft-2013b
# 297         fgvc-aircraft-2013b
#
#                                            backbone           ft_type  \
# 0    CLIP-convnext_base_w-laion_aesthetic-s13B-b82K  full_fine_tuning
# 1    CLIP-convnext_base_w-laion_aesthetic-s13B-b82K  full_fine_tuning
# 2    CLIP-convnext_base_w-laion_aesthetic-s13B-b82K  full_fine_tuning
# 3    CLIP-convnext_base_w-laion_aesthetic-s13B-b82K  full_fine_tuning
# 4    CLIP-convnext_base_w-laion_aesthetic-s13B-b82K  full_fine_tuning
# ..                                              ...               ...
# 273       vit_base_patch16_clip_224.laion2b_ft_in1k  full_fine_tuning
# 279       vit_base_patch16_224.augreg_in21k_ft_in1k  full_fine_tuning
# 285       vit_base_patch16_224.augreg_in21k_ft_in1k  full_fine_tuning
# 291      vit_small_patch16_224.augreg_in21k_ft_in1k  full_fine_tuning
# 297      vit_small_patch16_224.augreg_in21k_ft_in1k  full_fine_tuning
#
#     loss_function  seed  epochs       lr1       lr2  weight_decay1  \
# 0       TRADES_v2   1.0    50.0  0.000226  0.001246       0.001046
# 1       TRADES_v2   1.0    50.0  0.000179  0.005879       0.003203
# 2       TRADES_v2   1.0    50.0  0.000179  0.005879       0.003203
# 3       TRADES_v2   1.0    50.0  0.000179  0.005879       0.003203
# 4       TRADES_v2   1.0    50.0  0.000112  0.010016       0.000067
# ..            ...   ...     ...       ...       ...            ...
# 273    CLASSIC_AT   1.0    50.0  0.002048  0.000054       0.001418
# 279     TRADES_v2   1.0    50.0  0.005507  0.000066       0.003254
# 285    CLASSIC_AT   1.0    50.0  0.000674  0.000528       0.005708
# 291     TRADES_v2   1.0    50.0  0.000674  0.000528       0.005708
# 297    CLASSIC_AT   1.0    50.0  0.005507  0.000066       0.003254
#
#      weight_decay2  ... distance beta                      project_name  \
# 0         0.000072  ...     Linf  1.0  full_fine_tuning_50epochs_final3
# 1         0.003788  ...     Linf  1.0  full_fine_tuning_50epochs_final3
# 2         0.003788  ...     Linf  1.0  full_fine_tuning_50epochs_final3
# 3         0.003788  ...     Linf  1.0  full_fine_tuning_50epochs_final3
# 4         0.000002  ...     Linf  1.0  full_fine_tuning_50epochs_final3
# ..             ...  ...      ...  ...                               ...
# 273       0.000281  ...     Linf  1.0  full_fine_tuning_50epochs_final3
# 279       0.000001  ...     Linf  1.0  full_fine_tuning_50epochs_final3
# 285       0.001299  ...     Linf  1.0  full_fine_tuning_50epochs_final3
# 291       0.001299  ...     Linf  1.0  full_fine_tuning_50epochs_final3
# 297       0.000001  ...     Linf  1.0  full_fine_tuning_50epochs_final3
#
#                                                 exp_id  \
# 0    CLIP-convnext_base_w-laion_aesthetic-s13B-b82K...
# 1    CLIP-convnext_base_w-laion_aesthetic-s13B-b82K...
# 2    CLIP-convnext_base_w-laion_aesthetic-s13B-b82K...
# 3    CLIP-convnext_base_w-laion_aesthetic-s13B-b82K...
# 4    CLIP-convnext_base_w-laion_aesthetic-s13B-b82K...
# ..                                                 ...
# 273  vit_base_patch16_clip_224.laion2b_ft_in1k_fgvc...
# 279  vit_base_patch16_224.augreg_in21k_ft_in1k_fgvc...
# 285  vit_base_patch16_224.augreg_in21k_ft_in1k_fgvc...
# 291  vit_small_patch16_224.augreg_in21k_ft_in1k_fgv...
# 297  vit_small_patch16_224.augreg_in21k_ft_in1k_fgv...
#
#                   statedicts_path         trained_statedicts_path  \
# 0    ~/scratch/state_dicts_share/  ~/scratch/trained_state_dicts/
# 1    ~/scratch/state_dicts_share/  ~/scratch/trained_state_dicts/
# 2    ~/scratch/state_dicts_share/  ~/scratch/trained_state_dicts/
# 3    ~/scratch/state_dicts_share/  ~/scratch/trained_state_dicts/
# 4    ~/scratch/state_dicts_share/  ~/scratch/trained_state_dicts/
# ..                            ...                             ...
# 273  ~/scratch/state_dicts_share/  ~/scratch/trained_state_dicts/
# 279  ~/scratch/state_dicts_share/  ~/scratch/trained_state_dicts/
# 285  ~/scratch/state_dicts_share/  ~/scratch/trained_state_dicts/
# 291  ~/scratch/state_dicts_share/  ~/scratch/trained_state_dicts/
# 297  ~/scratch/state_dicts_share/  ~/scratch/trained_state_dicts/
#
#           datasets_path configs_path results_path                hpo_path
# 0    $SLURM_TMPDIR/data    ./configs    ./results  ~/scratch/hpo_results/
# 1    $SLURM_TMPDIR/data    ./configs    ./results  ~/scratch/hpo_results/
# 2    $SLURM_TMPDIR/data    ./configs    ./results  ~/scratch/hpo_results/
# 3    $SLURM_TMPDIR/data    ./configs    ./results  ~/scratch/hpo_results/
# 4    $SLURM_TMPDIR/data    ./configs    ./results  ~/scratch/hpo_results/
# ..                  ...          ...          ...                     ...
# 273  $SLURM_TMPDIR/data    ./configs    ./results  ~/scratch/hpo_results/
# 279  $SLURM_TMPDIR/data    ./configs    ./results  ~/scratch/hpo_results/
# 285  $SLURM_TMPDIR/data    ./configs    ./results  ~/scratch/hpo_results/
# 291  $SLURM_TMPDIR/data    ./configs    ./results  ~/scratch/hpo_results/
# 297  $SLURM_TMPDIR/data    ./configs    ./results  ~/scratch/hpo_results/
#
# [224 rows x 25 columns]

# %%
import numpy as np
import pandas as pd

# Assuming df is your DataFrame and has already dropped NaN rows:
df.dropna(inplace=True)

# Identify all rows that have duplicate exp_id values, including the original occurrence
duplicates = df[df.duplicated(subset=["exp_id"], keep=False)]

# Sort by exp_id for easier inspection
duplicates = duplicates.sort_values(by="exp_id")

# Display the duplicates
duplicates
# Out:
# Empty DataFrame
# Columns: [dataset, backbone, ft_type, loss_function, seed, epochs, lr1, lr2, weight_decay1, weight_decay2, scheduler, use_rs, epsilon, step_size, perturb_steps, distance, beta, project_name, exp_id, statedicts_path, trained_statedicts_path, datasets_path, configs_path, results_path, hpo_path]
# Index: []
#
# [0 rows x 25 columns]

# %%
cols_of_interest = [
    'loss_function', 'lr1', 'lr2', 'weight_decay1', 'weight_decay2'
]
df_filtered = df[cols_of_interest]

grouped_stats = df_filtered.groupby("loss_function").agg(['mean', 'median','std', 'count'])
grouped_stats
# Out:
#                     lr1                                 lr2            \
#                    mean    median       std count      mean    median
# loss_function
# CLASSIC_AT     0.001078  0.000386  0.003024   112  0.002645  0.000682
# TRADES_v2      0.000641  0.000226  0.001125   112  0.003560  0.001995
#
#                               weight_decay1                            \
#                     std count          mean    median       std count
# loss_function
# CLASSIC_AT     0.003496   112      0.001486  0.000439  0.002238   112
# TRADES_v2      0.003600   112      0.001494  0.000395  0.002191   112
#
#               weight_decay2
#                        mean    median       std count
# loss_function
# CLASSIC_AT         0.001606  0.000323  0.002055   112
# TRADES_v2          0.001461  0.000351  0.001955   112

# %%
import pandas as pd

# List of known architecture types
arch_types = [
    'convnext_base',
    'convnext_tiny',
    'deit_small',
    'resnet50',
    'vit_base',
    'vit_small'
]

# Function to extract arch_type from backbone string
def extract_arch_type(backbone):
    for arch in arch_types:
        if arch in backbone:
            return arch
    return 'other'

# Apply to the DataFrame
df_clean['arch_type'] = df_clean['backbone'].apply(extract_arch_type)

# Optional: filter to keep only known architectures
df_clean = df_clean[df_clean['arch_type'] != 'other']
df_clean.to_csv("../figures/hpo_dataset.csv", index=False)
# Compute grouped stats including count
stats = df_clean.groupby(['arch_type', 'loss_function'])[
    ['scheduler', 'lr1', 'lr2', 'weight_decay1', 'weight_decay2',]
].agg(['mean', 'median', 'std', 'count'])

stats.to_csv("../figures/hpo_dataset_analysis.csv", index=True)

# %%
stats
# Out:
#                             scheduler                              lr1  \
#                                  mean median       std count      mean
# arch_type     loss_function
# convnext_base CLASSIC_AT     0.481481    0.0  0.509175    27  0.000510
#               TRADES_v2      0.703704    1.0  0.465322    27  0.000531
# convnext_tiny CLASSIC_AT          0.6    1.0  0.507093    15  0.001481
#               TRADES_v2      0.533333    1.0  0.516398    15  0.000758
# deit_small    CLASSIC_AT     0.636364    1.0  0.504525    11  0.000353
#               TRADES_v2      0.636364    1.0  0.504525    11  0.000271
# resnet50      CLASSIC_AT     0.818182    1.0  0.404520    11  0.001565
#               TRADES_v2      0.818182    1.0  0.404520    11  0.002105
# vit_base      CLASSIC_AT      0.65625    1.0  0.482559    32  0.000623
#               TRADES_v2        0.4375    0.0  0.504016    32  0.000487
# vit_small     CLASSIC_AT        0.375    0.0  0.500000    16  0.002729
#               TRADES_v2         0.125    0.0  0.341565    16  0.000272
#
#                                                             lr2            \
#                                median       std count      mean    median
# arch_type     loss_function
# convnext_base CLASSIC_AT     0.000386  0.000477    27  0.002351  0.000356
#               TRADES_v2      0.000386  0.000415    27  0.003840  0.003260
# convnext_tiny CLASSIC_AT     0.000648  0.002661    15  0.002772  0.002682
#               TRADES_v2      0.000618  0.000679    15  0.003352  0.003140
# deit_small    CLASSIC_AT     0.000197  0.000273    11  0.002673  0.002690
#               TRADES_v2      0.000213  0.000185    11  0.004633  0.003602
# resnet50      CLASSIC_AT     0.000423  0.001911    11  0.003094  0.001806
#               TRADES_v2      0.000580  0.002297    11  0.002563  0.001918
# vit_base      CLASSIC_AT     0.000259  0.001081    32  0.002414  0.000511
#               TRADES_v2      0.000116  0.001231    32  0.003077  0.001088
# vit_small     CLASSIC_AT     0.000360  0.007150    16  0.003158  0.000810
#               TRADES_v2      0.000228  0.000230    16  0.004195  0.002012
#
#                                             weight_decay1                      \
#                                   std count          mean    median       std
# arch_type     loss_function
# convnext_base CLASSIC_AT     0.003922    27      0.001665  0.000478  0.002177
#               TRADES_v2      0.003705    27      0.001840  0.000481  0.002029
# convnext_tiny CLASSIC_AT     0.003014    15      0.001683  0.000183  0.002795
#               TRADES_v2      0.002374    15      0.001529  0.000028  0.002119
# deit_small    CLASSIC_AT     0.001995    11      0.002766  0.000401  0.003561
#               TRADES_v2      0.003831    11      0.001473  0.000273  0.002538
# resnet50      CLASSIC_AT     0.003061    11      0.000714  0.000004  0.001536
#               TRADES_v2      0.002052    11      0.001950  0.000071  0.003851
# vit_base      CLASSIC_AT     0.003692    32      0.001346  0.000478  0.001797
#               TRADES_v2      0.003883    32      0.001332  0.000408  0.001817
# vit_small     CLASSIC_AT     0.004186    16      0.000926  0.000250  0.001655
#               TRADES_v2      0.004518    16      0.000901  0.000395  0.001549
#
#                                   weight_decay2
#                             count          mean    median       std count
# arch_type     loss_function
# convnext_base CLASSIC_AT       27      0.001783  0.000613  0.002208    27
#               TRADES_v2        27      0.001916  0.001299  0.001931    27
# convnext_tiny CLASSIC_AT       15      0.001179  0.000082  0.001921    15
#               TRADES_v2        15      0.002089  0.001299  0.002375    15
# deit_small    CLASSIC_AT       11      0.001304  0.000762  0.001472    11
#               TRADES_v2        11      0.001501  0.000075  0.002694    11
# resnet50      CLASSIC_AT       11      0.001701  0.000281  0.002488    11
#               TRADES_v2        11      0.002153  0.001851  0.002391    11
# vit_base      CLASSIC_AT       32      0.001896  0.001162  0.002093    32
#               TRADES_v2        32      0.000888  0.000163  0.001476    32
# vit_small     CLASSIC_AT       16      0.001272  0.000064  0.002030    16
#               TRADES_v2        16      0.000749  0.000204  0.001016    16
