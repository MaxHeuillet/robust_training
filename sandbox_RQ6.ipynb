# %%
project_name = 'full_fine_tuning_5epochs_final1'

datas=( 'stanford_cars', 'caltech101', 'fgvc-aircraft-2013b', 'dtd', 'flowers-102', 'oxford-iiit-pet'  ) # 'eurosat' 

losses=( 'TRADES_v2', 'CLASSIC_AT' ) #  

backbones=(
  'convnext_tiny', 'robust_convnext_tiny', 'convnext_tiny.fb_in22k', 
  'deit_small_patch16_224.fb_in1k', 'robust_deit_small_patch16_224',
  'convnext_base', 'convnext_base.fb_in22k', 'robust_convnext_base', 
  'convnext_base.clip_laion2b', 'convnext_base.clip_laion2b_augreg',
  'vit_base_patch16_224.augreg_in1k', 'vit_base_patch16_224.augreg_in21k',
  'vit_base_patch16_224.dino', 'vit_base_patch16_224.mae', 'vit_base_patch16_224.orig_in21k',
  'vit_base_patch16_224.sam_in1k', 'vit_base_patch16_224_miil.in21k', 'robust_vit_base_patch16_224'  ) 

import pickle
import numpy as np

final_data = []

for backbone in backbones:
    for loss in losses:
        for data in datas:

            try:

                name ='{}_{}_{}'.format(backbone, data, loss)
                with open('./results/results_{}_{}_{}_{}.pkl'.format(project_name, backbone, data, loss), 'rb') as f:
                    saved_data = pickle.load(f)
                    result = saved_data[name]["statistics"]
                    result['backbone'] = backbone
                    result['dataset'] = data
                    result['loss_function'] = loss    

                    print(name, saved_data[name]["statistics"])
            except:
                result = {}
                result['backbone'] = backbone
                result['dataset'] = data
                result['loss_function'] = loss   
                result['clean_acc'] = np.nan
                result['robust_acc'] = np.nan 
                # print('not available')

            final_data.append(result)
# Out:
# convnext_tiny_stanford_cars_TRADES_v2 {'clean_acc': 0.3606666666666667, 'robust_acc': 0.004, 'backbone': 'convnext_tiny', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# convnext_tiny_caltech101_TRADES_v2 {'clean_acc': 0.9466666666666667, 'robust_acc': 0.8073333333333333, 'backbone': 'convnext_tiny', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# convnext_tiny_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.14466666666666667, 'robust_acc': 0.0006666666666666666, 'backbone': 'convnext_tiny', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# convnext_tiny_dtd_TRADES_v2 {'clean_acc': 0.49, 'robust_acc': 0.09083333333333334, 'backbone': 'convnext_tiny', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# convnext_tiny_flowers-102_TRADES_v2 {'clean_acc': 0.8506666666666667, 'robust_acc': 0.16233333333333333, 'backbone': 'convnext_tiny', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# convnext_tiny_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.852, 'robust_acc': 0.3305, 'backbone': 'convnext_tiny', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# convnext_tiny_stanford_cars_CLASSIC_AT {'clean_acc': 0.07466666666666667, 'robust_acc': 0.004666666666666667, 'backbone': 'convnext_tiny', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# convnext_tiny_caltech101_CLASSIC_AT {'clean_acc': 0.966, 'robust_acc': 0.8453333333333334, 'backbone': 'convnext_tiny', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# convnext_tiny_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.06333333333333334, 'robust_acc': 0.0, 'backbone': 'convnext_tiny', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# convnext_tiny_dtd_CLASSIC_AT {'clean_acc': 0.508, 'robust_acc': 0.0615, 'backbone': 'convnext_tiny', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# convnext_tiny_flowers-102_CLASSIC_AT {'clean_acc': 0.6013333333333334, 'robust_acc': 0.013333333333333334, 'backbone': 'convnext_tiny', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# convnext_tiny_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.7606666666666667, 'robust_acc': 0.39666666666666667, 'backbone': 'convnext_tiny', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_tiny_stanford_cars_TRADES_v2 {'clean_acc': 0.31266666666666665, 'robust_acc': 0.17333333333333334, 'backbone': 'robust_convnext_tiny', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# robust_convnext_tiny_caltech101_TRADES_v2 {'clean_acc': 0.9553333333333334, 'robust_acc': 0.8993333333333333, 'backbone': 'robust_convnext_tiny', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# robust_convnext_tiny_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.25466666666666665, 'robust_acc': 0.14866666666666667, 'backbone': 'robust_convnext_tiny', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# robust_convnext_tiny_dtd_TRADES_v2 {'clean_acc': 0.46, 'robust_acc': 0.26066666666666666, 'backbone': 'robust_convnext_tiny', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# robust_convnext_tiny_flowers-102_TRADES_v2 {'clean_acc': 0.53, 'robust_acc': 0.33866666666666667, 'backbone': 'robust_convnext_tiny', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# robust_convnext_tiny_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.878, 'robust_acc': 0.6646666666666666, 'backbone': 'robust_convnext_tiny', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# robust_convnext_tiny_stanford_cars_CLASSIC_AT {'clean_acc': 0.224, 'robust_acc': 0.13, 'backbone': 'robust_convnext_tiny', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_tiny_caltech101_CLASSIC_AT {'clean_acc': 0.9626666666666667, 'robust_acc': 0.9213333333333333, 'backbone': 'robust_convnext_tiny', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_tiny_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.09, 'robust_acc': 0.050666666666666665, 'backbone': 'robust_convnext_tiny', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_tiny_dtd_CLASSIC_AT {'clean_acc': 0.51, 'robust_acc': 0.36733333333333335, 'backbone': 'robust_convnext_tiny', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_tiny_flowers-102_CLASSIC_AT {'clean_acc': 0.43, 'robust_acc': 0.318, 'backbone': 'robust_convnext_tiny', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_tiny_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.8606666666666667, 'robust_acc': 0.7146666666666667, 'backbone': 'robust_convnext_tiny', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# convnext_tiny.fb_in22k_stanford_cars_TRADES_v2 {'clean_acc': 0.544, 'robust_acc': 0.174, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# convnext_tiny.fb_in22k_caltech101_TRADES_v2 {'clean_acc': 0.9673333333333334, 'robust_acc': 0.892, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# convnext_tiny.fb_in22k_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.4146666666666667, 'robust_acc': 0.08333333333333333, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# convnext_tiny.fb_in22k_dtd_TRADES_v2 {'clean_acc': 0.5946666666666667, 'robust_acc': 0.224, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# convnext_tiny.fb_in22k_flowers-102_TRADES_v2 {'clean_acc': 0.9333333333333333, 'robust_acc': 0.5513333333333333, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# convnext_tiny.fb_in22k_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.8726666666666667, 'robust_acc': 0.43133333333333335, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# convnext_tiny.fb_in22k_stanford_cars_CLASSIC_AT {'clean_acc': 0.194, 'robust_acc': 0.004666666666666667, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# convnext_tiny.fb_in22k_caltech101_CLASSIC_AT {'clean_acc': 0.9706666666666667, 'robust_acc': 0.8913333333333333, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# convnext_tiny.fb_in22k_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.18533333333333332, 'robust_acc': 0.0033333333333333335, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# convnext_tiny.fb_in22k_dtd_CLASSIC_AT {'clean_acc': 0.6471111111111111, 'robust_acc': 0.29688888888888887, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# convnext_tiny.fb_in22k_flowers-102_CLASSIC_AT {'clean_acc': 0.7746666666666666, 'robust_acc': 0.126, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# convnext_tiny.fb_in22k_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.844, 'robust_acc': 0.272, 'backbone': 'convnext_tiny.fb_in22k', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# deit_small_patch16_224.fb_in1k_stanford_cars_TRADES_v2 {'clean_acc': 0.374, 'robust_acc': 0.07733333333333334, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# deit_small_patch16_224.fb_in1k_caltech101_TRADES_v2 {'clean_acc': 0.9473333333333334, 'robust_acc': 0.8186666666666667, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# deit_small_patch16_224.fb_in1k_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.11466666666666667, 'robust_acc': 0.015333333333333332, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# deit_small_patch16_224.fb_in1k_dtd_TRADES_v2 {'clean_acc': 0.608, 'robust_acc': 0.224, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# deit_small_patch16_224.fb_in1k_flowers-102_TRADES_v2 {'clean_acc': 0.5, 'robust_acc': 0.136, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# deit_small_patch16_224.fb_in1k_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.9053333333333333, 'robust_acc': 0.502, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# deit_small_patch16_224.fb_in1k_stanford_cars_CLASSIC_AT {'clean_acc': 0.15933333333333333, 'robust_acc': 0.023333333333333334, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# deit_small_patch16_224.fb_in1k_caltech101_CLASSIC_AT {'clean_acc': 0.9493333333333334, 'robust_acc': 0.8413333333333334, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# deit_small_patch16_224.fb_in1k_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.076, 'robust_acc': 0.008, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# deit_small_patch16_224.fb_in1k_dtd_CLASSIC_AT {'clean_acc': 0.586, 'robust_acc': 0.31266666666666665, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# deit_small_patch16_224.fb_in1k_flowers-102_CLASSIC_AT {'clean_acc': 0.38133333333333336, 'robust_acc': 0.084, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# deit_small_patch16_224.fb_in1k_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.8546666666666667, 'robust_acc': 0.5206666666666667, 'backbone': 'deit_small_patch16_224.fb_in1k', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# robust_deit_small_patch16_224_stanford_cars_TRADES_v2 {'clean_acc': 0.356, 'robust_acc': 0.188, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# robust_deit_small_patch16_224_caltech101_TRADES_v2 {'clean_acc': 0.9593333333333334, 'robust_acc': 0.89, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# robust_deit_small_patch16_224_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.18333333333333332, 'robust_acc': 0.092, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# robust_deit_small_patch16_224_dtd_TRADES_v2 {'clean_acc': 0.5306666666666666, 'robust_acc': 0.3313333333333333, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# robust_deit_small_patch16_224_flowers-102_TRADES_v2 {'clean_acc': 0.5306666666666666, 'robust_acc': 0.374, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# robust_deit_small_patch16_224_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.8513333333333334, 'robust_acc': 0.6473333333333333, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# robust_deit_small_patch16_224_stanford_cars_CLASSIC_AT {'clean_acc': 0.19866666666666666, 'robust_acc': 0.10933333333333334, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# robust_deit_small_patch16_224_caltech101_CLASSIC_AT {'clean_acc': 0.962, 'robust_acc': 0.9046666666666666, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# robust_deit_small_patch16_224_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.13333333333333333, 'robust_acc': 0.08266666666666667, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# robust_deit_small_patch16_224_dtd_CLASSIC_AT {'clean_acc': 0.49066666666666664, 'robust_acc': 0.33866666666666667, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# robust_deit_small_patch16_224_flowers-102_CLASSIC_AT {'clean_acc': 0.45866666666666667, 'robust_acc': 0.336, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# robust_deit_small_patch16_224_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.834, 'robust_acc': 0.664, 'backbone': 'robust_deit_small_patch16_224', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# convnext_base_stanford_cars_TRADES_v2 {'clean_acc': 0.5793333333333334, 'robust_acc': 0.19066666666666668, 'backbone': 'convnext_base', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# convnext_base_caltech101_TRADES_v2 {'clean_acc': 0.9773333333333334, 'robust_acc': 0.922, 'backbone': 'convnext_base', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# convnext_base_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.24933333333333332, 'robust_acc': 0.088, 'backbone': 'convnext_base', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# convnext_base_dtd_TRADES_v2 {'clean_acc': 0.7206666666666667, 'robust_acc': 0.35533333333333333, 'backbone': 'convnext_base', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# convnext_base_flowers-102_TRADES_v2 {'clean_acc': 0.9573333333333334, 'robust_acc': 0.7913333333333333, 'backbone': 'convnext_base', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# convnext_base_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.9006666666666666, 'robust_acc': 0.63, 'backbone': 'convnext_base', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# convnext_base_stanford_cars_CLASSIC_AT {'clean_acc': 0.24466666666666667, 'robust_acc': 0.018666666666666668, 'backbone': 'convnext_base', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# convnext_base_caltech101_CLASSIC_AT {'clean_acc': 0.982, 'robust_acc': 0.9246666666666666, 'backbone': 'convnext_base', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# convnext_base_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.11733333333333333, 'robust_acc': 0.0065, 'backbone': 'convnext_base', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# convnext_base_dtd_CLASSIC_AT {'clean_acc': 0.68, 'robust_acc': 0.46066666666666667, 'backbone': 'convnext_base', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# convnext_base_flowers-102_CLASSIC_AT {'clean_acc': 0.94, 'robust_acc': 0.7873333333333333, 'backbone': 'convnext_base', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# convnext_base_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.9013333333333333, 'robust_acc': 0.642, 'backbone': 'convnext_base', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# convnext_base.fb_in22k_stanford_cars_TRADES_v2 {'clean_acc': 0.648, 'robust_acc': 0.29333333333333333, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# convnext_base.fb_in22k_caltech101_TRADES_v2 {'clean_acc': 0.982, 'robust_acc': 0.9246666666666666, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# convnext_base.fb_in22k_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.42533333333333334, 'robust_acc': 0.13466666666666666, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# convnext_base.fb_in22k_dtd_TRADES_v2 {'clean_acc': 0.6773333333333333, 'robust_acc': 0.3393333333333333, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# convnext_base.fb_in22k_flowers-102_TRADES_v2 {'clean_acc': 0.9486666666666667, 'robust_acc': 0.78, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# convnext_base.fb_in22k_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.9146666666666666, 'robust_acc': 0.658, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# convnext_base.fb_in22k_stanford_cars_CLASSIC_AT {'clean_acc': 0.23133333333333334, 'robust_acc': 0.012, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# convnext_base.fb_in22k_caltech101_CLASSIC_AT {'clean_acc': 0.9833333333333333, 'robust_acc': 0.928, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# convnext_base.fb_in22k_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.214, 'robust_acc': 0.004666666666666667, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# convnext_base.fb_in22k_dtd_CLASSIC_AT {'clean_acc': 0.714, 'robust_acc': 0.25183333333333335, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# convnext_base.fb_in22k_flowers-102_CLASSIC_AT {'clean_acc': 0.978, 'robust_acc': 0.818, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# convnext_base.fb_in22k_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.864, 'robust_acc': 0.6106666666666667, 'backbone': 'convnext_base.fb_in22k', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_base_stanford_cars_TRADES_v2 {'clean_acc': 0.356, 'robust_acc': 0.216, 'backbone': 'robust_convnext_base', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# robust_convnext_base_caltech101_TRADES_v2 {'clean_acc': 0.966, 'robust_acc': 0.9313333333333333, 'backbone': 'robust_convnext_base', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# robust_convnext_base_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.07533333333333334, 'robust_acc': 0.04, 'backbone': 'robust_convnext_base', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# robust_convnext_base_dtd_TRADES_v2 {'clean_acc': 0.45866666666666667, 'robust_acc': 0.3413333333333333, 'backbone': 'robust_convnext_base', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# robust_convnext_base_flowers-102_TRADES_v2 {'clean_acc': 0.428, 'robust_acc': 0.33266666666666667, 'backbone': 'robust_convnext_base', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# robust_convnext_base_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.486, 'robust_acc': 0.33466666666666667, 'backbone': 'robust_convnext_base', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# robust_convnext_base_stanford_cars_CLASSIC_AT {'clean_acc': 0.38, 'robust_acc': 0.31933333333333336, 'backbone': 'robust_convnext_base', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_base_caltech101_CLASSIC_AT {'clean_acc': 0.952, 'robust_acc': 0.9293333333333333, 'backbone': 'robust_convnext_base', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_base_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.21, 'robust_acc': 0.14666666666666667, 'backbone': 'robust_convnext_base', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_base_dtd_CLASSIC_AT {'clean_acc': 0.49533333333333335, 'robust_acc': 0.41133333333333333, 'backbone': 'robust_convnext_base', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_base_flowers-102_CLASSIC_AT {'clean_acc': 0.47, 'robust_acc': 0.41333333333333333, 'backbone': 'robust_convnext_base', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# robust_convnext_base_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.758, 'robust_acc': 0.672, 'backbone': 'robust_convnext_base', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_stanford_cars_TRADES_v2 {'clean_acc': 0.88, 'robust_acc': 0.6446666666666667, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_caltech101_TRADES_v2 {'clean_acc': 0.9553333333333334, 'robust_acc': 0.8333333333333334, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.4653333333333333, 'robust_acc': 0.17933333333333334, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_dtd_TRADES_v2 {'clean_acc': 0.6, 'robust_acc': 0.24533333333333332, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_flowers-102_TRADES_v2 {'clean_acc': 0.8586666666666667, 'robust_acc': 0.15, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.8766666666666667, 'robust_acc': 0.42, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_stanford_cars_CLASSIC_AT {'clean_acc': 0.9026666666666666, 'robust_acc': 0.612, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_caltech101_CLASSIC_AT {'clean_acc': 0.948, 'robust_acc': 0.8766666666666667, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.30466666666666664, 'robust_acc': 0.1, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_dtd_CLASSIC_AT {'clean_acc': 0.5626666666666666, 'robust_acc': 0.3313333333333333, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_flowers-102_CLASSIC_AT {'clean_acc': 0.5946666666666667, 'robust_acc': 0.29533333333333334, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.7613333333333333, 'robust_acc': 0.22133333333333333, 'backbone': 'convnext_base.clip_laion2b', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_augreg_stanford_cars_TRADES_v2 {'clean_acc': 0.8753333333333333, 'robust_acc': 0.614, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_augreg_caltech101_TRADES_v2 {'clean_acc': 0.948, 'robust_acc': 0.836, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_augreg_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.422, 'robust_acc': 0.014666666666666666, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_augreg_dtd_TRADES_v2 {'clean_acc': 0.5706666666666667, 'robust_acc': 0.24333333333333335, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_augreg_flowers-102_TRADES_v2 {'clean_acc': 0.7293333333333333, 'robust_acc': 0.278, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_augreg_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.802, 'robust_acc': 0.3506666666666667, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# convnext_base.clip_laion2b_augreg_stanford_cars_CLASSIC_AT {'clean_acc': 0.898, 'robust_acc': 0.654, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_augreg_caltech101_CLASSIC_AT {'clean_acc': 0.9166666666666666, 'robust_acc': 0.87, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_augreg_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.2906666666666667, 'robust_acc': 0.106, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_augreg_dtd_CLASSIC_AT {'clean_acc': 0.566, 'robust_acc': 0.346, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_augreg_flowers-102_CLASSIC_AT {'clean_acc': 0.30133333333333334, 'robust_acc': 0.14466666666666667, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# convnext_base.clip_laion2b_augreg_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.7766666666666666, 'robust_acc': 0.2811666666666667, 'backbone': 'convnext_base.clip_laion2b_augreg', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in1k_stanford_cars_TRADES_v2 {'clean_acc': 0.24266666666666667, 'robust_acc': 0.04, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in1k_caltech101_TRADES_v2 {'clean_acc': 0.9266666666666666, 'robust_acc': 0.814, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in1k_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.114, 'robust_acc': 0.0175, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in1k_dtd_TRADES_v2 {'clean_acc': 0.5346666666666666, 'robust_acc': 0.23933333333333334, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in1k_flowers-102_TRADES_v2 {'clean_acc': 0.04133333333333333, 'robust_acc': 0.019333333333333334, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in1k_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.8653333333333333, 'robust_acc': 0.5208333333333334, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in1k_stanford_cars_CLASSIC_AT {'clean_acc': 0.13066666666666665, 'robust_acc': 0.028, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in1k_caltech101_CLASSIC_AT {'clean_acc': 0.9126666666666666, 'robust_acc': 0.8286666666666667, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in1k_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.010666666666666666, 'robust_acc': 0.0, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in1k_dtd_CLASSIC_AT {'clean_acc': 0.5306666666666666, 'robust_acc': 0.28933333333333333, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in1k_flowers-102_CLASSIC_AT {'clean_acc': 0.336, 'robust_acc': 0.06333333333333334, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in1k_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.7793333333333333, 'robust_acc': 0.5553333333333333, 'backbone': 'vit_base_patch16_224.augreg_in1k', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in21k_stanford_cars_TRADES_v2 {'clean_acc': 0.264, 'robust_acc': 0.0033333333333333335, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in21k_caltech101_TRADES_v2 {'clean_acc': 0.96, 'robust_acc': 0.848, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in21k_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.01, 'robust_acc': 0.01, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in21k_dtd_TRADES_v2 {'clean_acc': 0.4166666666666667, 'robust_acc': 0.04683333333333333, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'dtd', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in21k_flowers-102_TRADES_v2 {'clean_acc': 0.6573333333333333, 'robust_acc': 0.09066666666666667, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'flowers-102', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in21k_oxford-iiit-pet_TRADES_v2 {'clean_acc': 0.7873333333333333, 'robust_acc': 0.298, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'oxford-iiit-pet', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.augreg_in21k_stanford_cars_CLASSIC_AT {'clean_acc': 0.006666666666666667, 'robust_acc': 0.0006666666666666666, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'stanford_cars', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in21k_caltech101_CLASSIC_AT {'clean_acc': 0.924, 'robust_acc': 0.7886666666666666, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'caltech101', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in21k_fgvc-aircraft-2013b_CLASSIC_AT {'clean_acc': 0.012, 'robust_acc': 0.002, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in21k_dtd_CLASSIC_AT {'clean_acc': 0.5306666666666666, 'robust_acc': 0.277, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'dtd', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in21k_flowers-102_CLASSIC_AT {'clean_acc': 0.9293333333333333, 'robust_acc': 0.6966666666666667, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'flowers-102', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.augreg_in21k_oxford-iiit-pet_CLASSIC_AT {'clean_acc': 0.7046666666666667, 'robust_acc': 0.45466666666666666, 'backbone': 'vit_base_patch16_224.augreg_in21k', 'dataset': 'oxford-iiit-pet', 'loss_function': 'CLASSIC_AT'}
# vit_base_patch16_224.dino_stanford_cars_TRADES_v2 {'clean_acc': 0.3373333333333333, 'robust_acc': 0.025333333333333333, 'backbone': 'vit_base_patch16_224.dino', 'dataset': 'stanford_cars', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.dino_caltech101_TRADES_v2 {'clean_acc': 0.9313333333333333, 'robust_acc': 0.824, 'backbone': 'vit_base_patch16_224.dino', 'dataset': 'caltech101', 'loss_function': 'TRADES_v2'}
# vit_base_patch16_224.dino_fgvc-aircraft-2013b_TRADES_v2 {'clean_acc': 0.18933333333333333, 'robust_acc': 0.03866666666666667, 'backbone': 'vit_base_patch16_224.dino', 'dataset': 'fgvc-aircraft-2013b', 'loss_function': 'TRADES_v2'}

# %%
import pickle
import numpy as np

datas=( 'stanford_cars', 'caltech101', 'fgvc-aircraft-2013b', 'dtd', 'flowers-102', 'oxford-iiit-pet'  ) #'imagenette2' 'eurosat' 

losses=( 'TRADES_v2', 'CLASSIC_AT' ) #  

backbones=(
  'convnext_tiny', 'robust_convnext_tiny', 'convnext_tiny.fb_in22k', 
  'deit_small_patch16_224.fb_in1k', 'robust_deit_small_patch16_224',
  'convnext_base', 'convnext_base.fb_in22k', 'robust_convnext_base', 
  'convnext_base.clip_laion2b', 'convnext_base.clip_laion2b_augreg',
  'vit_base_patch16_224.augreg_in1k', 'vit_base_patch16_224.augreg_in21k',
  'vit_base_patch16_224.dino', 'vit_base_patch16_224.mae', 'vit_base_patch16_224.orig_in21k',
  'vit_base_patch16_224.sam_in1k', 'vit_base_patch16_224_miil.in21k', 'robust_vit_base_patch16_224'  ) 

final_data1 = []
final_data2 = []

for backbone in backbones:
    for loss in losses:
        for data in datas:

            try:

                name ='{}_{}_{}'.format(backbone, data, loss)
                project_name = 'full_fine_tuning_5epochs_final1'
                with open('./results/results_{}_{}_{}_{}.pkl'.format(project_name, backbone, data, loss), 'rb') as f:
                    saved_data = pickle.load(f)
                    result = saved_data[name]["statistics"]
                    result['backbone'] = backbone
                    result['dataset'] = data
                    result['loss_function'] = loss    
            except:
                result = {}
                result['backbone'] = backbone
                result['dataset'] = data
                result['loss_function'] = loss   
                result['clean_acc'] = np.nan
                result['robust_acc'] = np.nan 
                # print('not available')

            final_data1.append(result)

            try:

                name ='{}_{}_{}'.format(backbone, data, loss)
                project_name = 'full_fine_tuning_50epochs_final1'
                with open('./results/results_{}_{}_{}_{}.pkl'.format(project_name, backbone, data, loss), 'rb') as f:
                    saved_data = pickle.load(f)
                    result = saved_data[name]["statistics"]
                    result['backbone'] = backbone
                    result['dataset'] = data
                    result['loss_function'] = loss    
            except:
                result = {}
                result['backbone'] = backbone
                result['dataset'] = data
                result['loss_function'] = loss   
                result['clean_acc'] = np.nan
                result['robust_acc'] = np.nan 
                # print('not available')

            final_data2.append(result)

# %%
import pandas as pd

df = pd.DataFrame(final_data)
df
# Out:
#      clean_acc  robust_acc                     backbone              dataset  \
# 0     0.360667    0.004000                convnext_tiny        stanford_cars
# 1     0.946667    0.807333                convnext_tiny           caltech101
# 2     0.144667    0.000667                convnext_tiny  fgvc-aircraft-2013b
# 3     0.490000    0.090833                convnext_tiny                  dtd
# 4     0.850667    0.162333                convnext_tiny          flowers-102
# ..         ...         ...                          ...                  ...
# 211        NaN         NaN  robust_vit_base_patch16_224           caltech101
# 212        NaN         NaN  robust_vit_base_patch16_224  fgvc-aircraft-2013b
# 213        NaN         NaN  robust_vit_base_patch16_224                  dtd
# 214        NaN         NaN  robust_vit_base_patch16_224          flowers-102
# 215        NaN         NaN  robust_vit_base_patch16_224      oxford-iiit-pet
#
#     loss_function
# 0       TRADES_v2
# 1       TRADES_v2
# 2       TRADES_v2
# 3       TRADES_v2
# 4       TRADES_v2
# ..            ...
# 211    CLASSIC_AT
# 212    CLASSIC_AT
# 213    CLASSIC_AT
# 214    CLASSIC_AT
# 215    CLASSIC_AT
#
# [216 rows x 5 columns]

# %%
data_updated = df.copy()

# Combine clean_acc and robust_acc as independent metrics for ranking
data_updated['total_acc'] = data_updated['clean_acc'] + data_updated['robust_acc']  # Sum of scores per dataset

# Aggregate total_acc across all datasets for each backbone + loss combination
aggregated_data_no_avg = data_updated.groupby(['backbone', 'loss_function']).agg(
    total_sum=('total_acc', 'sum'),  # Total sum of all scores across datasets
    total_geom_mean=('total_acc', lambda x: np.prod(x) ** (1 / len(x))),  # Geometric mean
).reset_index()

# Rank based on these combined scores
aggregated_data_no_avg['rank_total_sum'] = aggregated_data_no_avg['total_sum'].rank(ascending=False)
aggregated_data_no_avg['rank_total_geom_mean'] = aggregated_data_no_avg['total_geom_mean'].rank(ascending=False)

# Sort by sum ranking for presentation
ranked_aggregated_data_no_avg = aggregated_data_no_avg.sort_values(by='rank_total_sum')

ranked_aggregated_data_no_avg

# tools.display_dataframe_to_user(name="Ranked Backbone and Loss Combinations Without Averaging", dataframe=ranked_aggregated_data_no_avg)
# Out:
#                              backbone loss_function  total_sum  \
# 7              convnext_base.fb_in22k     TRADES_v2   7.726000
# 1                       convnext_base     TRADES_v2   7.362000
# 3          convnext_base.clip_laion2b     TRADES_v2   7.108667
# 0                       convnext_base    CLASSIC_AT   6.705167
# 5   convnext_base.clip_laion2b_augreg     TRADES_v2   6.684000
# 11             convnext_tiny.fb_in22k     TRADES_v2   6.682667
# 6              convnext_base.fb_in22k    CLASSIC_AT   6.609833
# 2          convnext_base.clip_laion2b    CLASSIC_AT   6.510667
# 33      vit_base_patch16_224.sam_in1k     TRADES_v2   6.211667
# 14               robust_convnext_base    CLASSIC_AT   6.157333
# 4   convnext_base.clip_laion2b_augreg    CLASSIC_AT   6.151167
# 30    vit_base_patch16_224.orig_in21k    CLASSIC_AT   6.129333
# 31    vit_base_patch16_224.orig_in21k     TRADES_v2   6.110667
# 19      robust_deit_small_patch16_224     TRADES_v2   5.934000
# 17               robust_convnext_tiny     TRADES_v2   5.876000
# 32      vit_base_patch16_224.sam_in1k    CLASSIC_AT   5.785333
# 16               robust_convnext_tiny    CLASSIC_AT   5.579333
# 18      robust_deit_small_patch16_224    CLASSIC_AT   5.512667
# 24  vit_base_patch16_224.augreg_in21k    CLASSIC_AT   5.327000
# 27          vit_base_patch16_224.dino     TRADES_v2   5.284667
# 13     deit_small_patch16_224.fb_in1k     TRADES_v2   5.222667
# 10             convnext_tiny.fb_in22k    CLASSIC_AT   5.210000
# 9                       convnext_tiny     TRADES_v2   5.040333
# 26          vit_base_patch16_224.dino    CLASSIC_AT   5.013333
# 15               robust_convnext_base     TRADES_v2   4.966000
# 12     deit_small_patch16_224.fb_in1k    CLASSIC_AT   4.796667
# 22   vit_base_patch16_224.augreg_in1k    CLASSIC_AT   4.464667
# 25  vit_base_patch16_224.augreg_in21k     TRADES_v2   4.392167
# 23   vit_base_patch16_224.augreg_in1k     TRADES_v2   4.375667
# 8                       convnext_tiny    CLASSIC_AT   4.295500
# 35    vit_base_patch16_224_miil.in21k     TRADES_v2   3.729833
# 29           vit_base_patch16_224.mae     TRADES_v2   2.900667
# 28           vit_base_patch16_224.mae    CLASSIC_AT   2.474667
# 34    vit_base_patch16_224_miil.in21k    CLASSIC_AT   1.802000
# 21        robust_vit_base_patch16_224     TRADES_v2   0.000000
# 20        robust_vit_base_patch16_224    CLASSIC_AT   0.000000
#
#     total_geom_mean  rank_total_sum  rank_total_geom_mean
# 7          1.185647             1.0                   1.0
# 1          1.060291             2.0                   3.0
# 3          1.117139             3.0                   2.0
# 0          0.757592             4.0                  18.0
# 5          1.015484             5.0                   4.0
# 11         1.008759             6.0                   5.0
# 6          0.798982             7.0                  17.0
# 2          0.977887             8.0                   8.0
# 33         0.907308             9.0                   9.0
# 14         0.901682            10.0                  10.0
# 4          0.882778            11.0                  11.0
# 30         0.836598            12.0                  13.0
# 31         0.833054            13.0                  14.0
# 19         0.828633            14.0                  16.0
# 17         0.839919            15.0                  12.0
# 32         0.831462            16.0                  15.0
# 16         0.677827            17.0                  21.0
# 18         0.704828            18.0                  20.0
# 24         0.253870            19.0                  34.0
# 27         0.712875            20.0                  19.0
# 13         0.652481            21.0                  22.0
# 10         0.636063            22.0                  24.0
# 9          0.633566            23.0                  25.0
# 26         0.636769            24.0                  23.0
# 15         0.629976            25.0                  26.0
# 12         0.500942            26.0                  27.0
# 22         0.329852            27.0                  33.0
# 25         0.392162            28.0                  30.0
# 23         0.401856            29.0                  28.0
# 8          0.393049            30.0                  29.0
# 35         0.376574            31.0                  31.0
# 29         0.372993            32.0                  32.0
# 28         0.194835            33.0                  35.0
# 34         0.149049            34.0                  36.0
# 21         1.000000            35.5                   6.5
# 20         1.000000            35.5                   6.5

# %%
# Pivot the table to group by 'backbone' and 'loss_function' in rows and create a hierarchical structure with 'dataset' as column index
grouped_df = df.pivot_table(
    index=['backbone', 'loss_function'], 
    columns='dataset', 
    values=[ 'clean_acc',  ], #'robust_acc'
    dropna=False
)

grouped_df #.to_csv('results_acc.csv' )
# Out:
#                                                  clean_acc            \
# dataset                                         caltech101       dtd
# backbone                          loss_function
# convnext_base                     CLASSIC_AT      0.982000  0.680000
#                                   TRADES_v2       0.977333  0.720667
# convnext_base.clip_laion2b        CLASSIC_AT      0.948000  0.562667
#                                   TRADES_v2       0.955333  0.600000
# convnext_base.clip_laion2b_augreg CLASSIC_AT      0.916667  0.566000
#                                   TRADES_v2       0.948000  0.570667
# convnext_base.fb_in22k            CLASSIC_AT      0.983333  0.714000
#                                   TRADES_v2       0.982000  0.677333
# convnext_tiny                     CLASSIC_AT      0.966000  0.508000
#                                   TRADES_v2       0.946667  0.490000
# convnext_tiny.fb_in22k            CLASSIC_AT      0.970667  0.647111
#                                   TRADES_v2       0.967333  0.594667
# deit_small_patch16_224.fb_in1k    CLASSIC_AT      0.949333  0.586000
#                                   TRADES_v2       0.947333  0.608000
# robust_convnext_base              CLASSIC_AT      0.952000  0.495333
#                                   TRADES_v2       0.966000  0.458667
# robust_convnext_tiny              CLASSIC_AT      0.962667  0.510000
#                                   TRADES_v2       0.955333  0.460000
# robust_deit_small_patch16_224     CLASSIC_AT      0.962000  0.490667
#                                   TRADES_v2       0.959333  0.530667
# robust_vit_base_patch16_224       CLASSIC_AT           NaN       NaN
#                                   TRADES_v2            NaN       NaN
# vit_base_patch16_224.augreg_in1k  CLASSIC_AT      0.912667  0.530667
#                                   TRADES_v2       0.926667  0.534667
# vit_base_patch16_224.augreg_in21k CLASSIC_AT      0.924000  0.530667
#                                   TRADES_v2       0.960000  0.416667
# vit_base_patch16_224.dino         CLASSIC_AT      0.956667  0.584000
#                                   TRADES_v2       0.931333  0.539333
# vit_base_patch16_224.mae          CLASSIC_AT      0.806667  0.318000
#                                   TRADES_v2       0.860000  0.333333
# vit_base_patch16_224.orig_in21k   CLASSIC_AT      0.877333  0.589333
#                                   TRADES_v2       0.942000  0.684667
# vit_base_patch16_224.sam_in1k     CLASSIC_AT      0.920667  0.539333
#                                   TRADES_v2       0.957333  0.608667
# vit_base_patch16_224_miil.in21k   CLASSIC_AT      0.326667  0.328000
#                                   TRADES_v2       0.888667  0.452667
#
#                                                                      \
# dataset                                         fgvc-aircraft-2013b
# backbone                          loss_function
# convnext_base                     CLASSIC_AT               0.117333
#                                   TRADES_v2                0.249333
# convnext_base.clip_laion2b        CLASSIC_AT               0.304667
#                                   TRADES_v2                0.465333
# convnext_base.clip_laion2b_augreg CLASSIC_AT               0.290667
#                                   TRADES_v2                0.422000
# convnext_base.fb_in22k            CLASSIC_AT               0.214000
#                                   TRADES_v2                0.425333
# convnext_tiny                     CLASSIC_AT               0.063333
#                                   TRADES_v2                0.144667
# convnext_tiny.fb_in22k            CLASSIC_AT               0.185333
#                                   TRADES_v2                0.414667
# deit_small_patch16_224.fb_in1k    CLASSIC_AT               0.076000
#                                   TRADES_v2                0.114667
# robust_convnext_base              CLASSIC_AT               0.210000
#                                   TRADES_v2                0.075333
# robust_convnext_tiny              CLASSIC_AT               0.090000
#                                   TRADES_v2                0.254667
# robust_deit_small_patch16_224     CLASSIC_AT               0.133333
#                                   TRADES_v2                0.183333
# robust_vit_base_patch16_224       CLASSIC_AT                    NaN
#                                   TRADES_v2                     NaN
# vit_base_patch16_224.augreg_in1k  CLASSIC_AT               0.010667
#                                   TRADES_v2                0.114000
# vit_base_patch16_224.augreg_in21k CLASSIC_AT               0.012000
#                                   TRADES_v2                0.010000
# vit_base_patch16_224.dino         CLASSIC_AT               0.145333
#                                   TRADES_v2                0.189333
# vit_base_patch16_224.mae          CLASSIC_AT               0.033333
#                                   TRADES_v2                0.036667
# vit_base_patch16_224.orig_in21k   CLASSIC_AT               0.216000
#                                   TRADES_v2                0.237333
# vit_base_patch16_224.sam_in1k     CLASSIC_AT               0.214667
#                                   TRADES_v2                0.272667
# vit_base_patch16_224_miil.in21k   CLASSIC_AT               0.022667
#                                   TRADES_v2                0.064000
#
#                                                                              \
# dataset                                         flowers-102 oxford-iiit-pet
# backbone                          loss_function
# convnext_base                     CLASSIC_AT       0.940000        0.901333
#                                   TRADES_v2        0.957333        0.900667
# convnext_base.clip_laion2b        CLASSIC_AT       0.594667        0.761333
#                                   TRADES_v2        0.858667        0.876667
# convnext_base.clip_laion2b_augreg CLASSIC_AT       0.301333        0.776667
#                                   TRADES_v2        0.729333        0.802000
# convnext_base.fb_in22k            CLASSIC_AT       0.978000        0.864000
#                                   TRADES_v2        0.948667        0.914667
# convnext_tiny                     CLASSIC_AT       0.601333        0.760667
#                                   TRADES_v2        0.850667        0.852000
# convnext_tiny.fb_in22k            CLASSIC_AT       0.774667        0.844000
#                                   TRADES_v2        0.933333        0.872667
# deit_small_patch16_224.fb_in1k    CLASSIC_AT       0.381333        0.854667
#                                   TRADES_v2        0.500000        0.905333
# robust_convnext_base              CLASSIC_AT       0.470000        0.758000
#                                   TRADES_v2        0.428000        0.486000
# robust_convnext_tiny              CLASSIC_AT       0.430000        0.860667
#                                   TRADES_v2        0.530000        0.878000
# robust_deit_small_patch16_224     CLASSIC_AT       0.458667        0.834000
#                                   TRADES_v2        0.530667        0.851333
# robust_vit_base_patch16_224       CLASSIC_AT            NaN             NaN
#                                   TRADES_v2             NaN             NaN
# vit_base_patch16_224.augreg_in1k  CLASSIC_AT       0.336000        0.779333
#                                   TRADES_v2        0.041333        0.865333
# vit_base_patch16_224.augreg_in21k CLASSIC_AT       0.929333        0.704667
#                                   TRADES_v2        0.657333        0.787333
# vit_base_patch16_224.dino         CLASSIC_AT       0.350000        0.832000
#                                   TRADES_v2        0.663333        0.820000
# vit_base_patch16_224.mae          CLASSIC_AT       0.090000        0.154667
#                                   TRADES_v2             NaN        0.647333
# vit_base_patch16_224.orig_in21k   CLASSIC_AT       0.882667        0.820667
#                                   TRADES_v2        0.942000        0.910667
# vit_base_patch16_224.sam_in1k     CLASSIC_AT       0.474000        0.859333
#                                   TRADES_v2        0.690000        0.915333
# vit_base_patch16_224_miil.in21k   CLASSIC_AT       0.284667        0.122000
#                                   TRADES_v2        0.704667        0.514667
#
#
# dataset                                         stanford_cars
# backbone                          loss_function
# convnext_base                     CLASSIC_AT         0.244667
#                                   TRADES_v2          0.579333
# convnext_base.clip_laion2b        CLASSIC_AT         0.902667
#                                   TRADES_v2          0.880000
# convnext_base.clip_laion2b_augreg CLASSIC_AT         0.898000
#                                   TRADES_v2          0.875333
# convnext_base.fb_in22k            CLASSIC_AT         0.231333
#                                   TRADES_v2          0.648000
# convnext_tiny                     CLASSIC_AT         0.074667
#                                   TRADES_v2          0.360667
# convnext_tiny.fb_in22k            CLASSIC_AT         0.194000
#                                   TRADES_v2          0.544000
# deit_small_patch16_224.fb_in1k    CLASSIC_AT         0.159333
#                                   TRADES_v2          0.374000
# robust_convnext_base              CLASSIC_AT         0.380000
#                                   TRADES_v2          0.356000
# robust_convnext_tiny              CLASSIC_AT         0.224000
#                                   TRADES_v2          0.312667
# robust_deit_small_patch16_224     CLASSIC_AT         0.198667
#                                   TRADES_v2          0.356000
# robust_vit_base_patch16_224       CLASSIC_AT              NaN
#                                   TRADES_v2               NaN
# vit_base_patch16_224.augreg_in1k  CLASSIC_AT         0.130667
#                                   TRADES_v2          0.242667
# vit_base_patch16_224.augreg_in21k CLASSIC_AT         0.006667
#                                   TRADES_v2          0.264000
# vit_base_patch16_224.dino         CLASSIC_AT         0.226000
#                                   TRADES_v2          0.337333
# vit_base_patch16_224.mae          CLASSIC_AT         0.040000
#                                   TRADES_v2          0.078000
# vit_base_patch16_224.orig_in21k   CLASSIC_AT         0.260667
#                                   TRADES_v2          0.384667
# vit_base_patch16_224.sam_in1k     CLASSIC_AT         0.358000
#                                   TRADES_v2          0.506000
# vit_base_patch16_224_miil.in21k   CLASSIC_AT         0.008667
#                                   TRADES_v2          0.089333

# %%
# Pivot the table to group by 'backbone' and 'loss_function' in rows and create a hierarchical structure with 'dataset' as column index
grouped_df = df.pivot_table(
    index=['backbone', 'loss_function'], 
    columns='dataset', 
    values=['robust_acc', ], #
    dropna=False
)

grouped_df
# Out:
#                                                 robust_acc           \
# dataset                                         caltech101      dtd
# backbone                          loss_function
# convnext_base                     CLASSIC_AT      0.934000 0.516667
#                                   TRADES_v2       0.940000 0.536667
# convnext_base.clip_laion2b        CLASSIC_AT      0.916000 0.469333
#                                   TRADES_v2       0.899333 0.490667
# convnext_base.clip_laion2b_augreg CLASSIC_AT      0.920667 0.495333
#                                   TRADES_v2       0.925333 0.496000
# convnext_base.fb_in22k            CLASSIC_AT      0.932000 0.531333
#                                   TRADES_v2       0.938667 0.527333
# convnext_tiny                     CLASSIC_AT      0.903333 0.390000
#                                   TRADES_v2       0.906000 0.460000
# convnext_tiny.fb_in22k            CLASSIC_AT      0.916000 0.472000
#                                   TRADES_v2       0.922000 0.502000
# deit_small_patch16_224.fb_in1k    CLASSIC_AT      0.874667 0.308667
#                                   TRADES_v2       0.880667 0.401333
# robust_convnext_base              CLASSIC_AT      0.934667 0.479333
#                                   TRADES_v2       0.948000 0.520000
# robust_convnext_tiny              CLASSIC_AT      0.930667 0.478667
#                                   TRADES_v2       0.941333 0.502000
# robust_deit_small_patch16_224     CLASSIC_AT      0.903333 0.415333
#                                   TRADES_v2       0.920667 0.430667
# vit_base_patch16_224.augreg_in1k  CLASSIC_AT      0.858000 0.369333
#                                   TRADES_v2       0.881333 0.414000
# vit_base_patch16_224.augreg_in21k CLASSIC_AT      0.887333 0.412667
#                                   TRADES_v2       0.920667 0.388667
# vit_base_patch16_224.dino         CLASSIC_AT      0.895333 0.370000
#                                   TRADES_v2       0.886000 0.396667
# vit_base_patch16_224.mae          CLASSIC_AT           NaN 0.320000
#                                   TRADES_v2       0.799333 0.382667
# vit_base_patch16_224.orig_in21k   CLASSIC_AT           NaN 0.376000
#                                   TRADES_v2       0.903333 0.440667
# vit_base_patch16_224.sam_in1k     CLASSIC_AT           NaN 0.364000
#                                   TRADES_v2       0.892667 0.438000
# vit_base_patch16_224_miil.in21k   CLASSIC_AT           NaN 0.263333
#                                   TRADES_v2       0.899333 0.398667
#
#                                                                      \
# dataset                                         fgvc-aircraft-2013b
# backbone                          loss_function
# convnext_base                     CLASSIC_AT               0.350667
#                                   TRADES_v2                0.627333
# convnext_base.clip_laion2b        CLASSIC_AT               0.574667
#                                   TRADES_v2                0.500667
# convnext_base.clip_laion2b_augreg CLASSIC_AT               0.582667
#                                   TRADES_v2                0.622000
# convnext_base.fb_in22k            CLASSIC_AT               0.336667
#                                   TRADES_v2                0.627333
# convnext_tiny                     CLASSIC_AT               0.392667
#                                   TRADES_v2                0.357333
# convnext_tiny.fb_in22k            CLASSIC_AT               0.048667
#                                   TRADES_v2                0.600667
# deit_small_patch16_224.fb_in1k    CLASSIC_AT               0.259333
#                                   TRADES_v2                0.456000
# robust_convnext_base              CLASSIC_AT               0.606667
#                                   TRADES_v2                0.642667
# robust_convnext_tiny              CLASSIC_AT               0.430000
#                                   TRADES_v2                0.619333
# robust_deit_small_patch16_224     CLASSIC_AT               0.486667
#                                   TRADES_v2                0.512000
# vit_base_patch16_224.augreg_in1k  CLASSIC_AT               0.182667
#                                   TRADES_v2                0.220000
# vit_base_patch16_224.augreg_in21k CLASSIC_AT               0.088000
#                                   TRADES_v2                0.298667
# vit_base_patch16_224.dino         CLASSIC_AT               0.376000
#                                   TRADES_v2                0.477333
# vit_base_patch16_224.mae          CLASSIC_AT               0.149333
#                                   TRADES_v2                0.437333
# vit_base_patch16_224.orig_in21k   CLASSIC_AT               0.337333
#                                   TRADES_v2                0.506667
# vit_base_patch16_224.sam_in1k     CLASSIC_AT               0.409333
#                                   TRADES_v2                0.536000
# vit_base_patch16_224_miil.in21k   CLASSIC_AT               0.010000
#                                   TRADES_v2                0.128000
#
#                                                                              \
# dataset                                         flowers-102 oxford-iiit-pet
# backbone                          loss_function
# convnext_base                     CLASSIC_AT       0.886000        0.712667
#                                   TRADES_v2        0.865333             NaN
# convnext_base.clip_laion2b        CLASSIC_AT       0.727333        0.654667
#                                   TRADES_v2        0.770000             NaN
# convnext_base.clip_laion2b_augreg CLASSIC_AT       0.768667        0.643333
#                                   TRADES_v2        0.768667             NaN
# convnext_base.fb_in22k            CLASSIC_AT       0.896667        0.696000
#                                   TRADES_v2        0.880667             NaN
# convnext_tiny                     CLASSIC_AT       0.295333        0.586667
#                                   TRADES_v2        0.815333             NaN
# convnext_tiny.fb_in22k            CLASSIC_AT       0.851333        0.637333
#                                   TRADES_v2        0.843333             NaN
# deit_small_patch16_224.fb_in1k    CLASSIC_AT       0.574667        0.588667
#                                   TRADES_v2        0.670667             NaN
# robust_convnext_base              CLASSIC_AT       0.703333        0.735333
#                                   TRADES_v2        0.747333             NaN
# robust_convnext_tiny              CLASSIC_AT       0.678000        0.751333
#                                   TRADES_v2        0.736667             NaN
# robust_deit_small_patch16_224     CLASSIC_AT       0.590000        0.704000
#                                   TRADES_v2        0.680000             NaN
# vit_base_patch16_224.augreg_in1k  CLASSIC_AT       0.610667        0.590667
#                                   TRADES_v2             NaN             NaN
# vit_base_patch16_224.augreg_in21k CLASSIC_AT       0.848000        0.004000
#                                   TRADES_v2        0.879333             NaN
# vit_base_patch16_224.dino         CLASSIC_AT       0.676667        0.630000
#                                   TRADES_v2        0.733333             NaN
# vit_base_patch16_224.mae          CLASSIC_AT       0.512000        0.430000
#                                   TRADES_v2        0.606000             NaN
# vit_base_patch16_224.orig_in21k   CLASSIC_AT       0.804667        0.495333
#                                   TRADES_v2        0.826667             NaN
# vit_base_patch16_224.sam_in1k     CLASSIC_AT       0.586000        0.638667
#                                   TRADES_v2        0.739333             NaN
# vit_base_patch16_224_miil.in21k   CLASSIC_AT       0.338667        0.017333
#                                   TRADES_v2        0.710000        0.606667
#
#
# dataset                                         stanford_cars
# backbone                          loss_function
# convnext_base                     CLASSIC_AT              NaN
#                                   TRADES_v2               NaN
# convnext_base.clip_laion2b        CLASSIC_AT              NaN
#                                   TRADES_v2               NaN
# convnext_base.clip_laion2b_augreg CLASSIC_AT              NaN
#                                   TRADES_v2               NaN
# convnext_base.fb_in22k            CLASSIC_AT              NaN
#                                   TRADES_v2               NaN
# convnext_tiny                     CLASSIC_AT         0.420000
#                                   TRADES_v2          0.513333
# convnext_tiny.fb_in22k            CLASSIC_AT         0.334000
#                                   TRADES_v2          0.620667
# deit_small_patch16_224.fb_in1k    CLASSIC_AT         0.286667
#                                   TRADES_v2          0.492000
# robust_convnext_base              CLASSIC_AT              NaN
#                                   TRADES_v2               NaN
# robust_convnext_tiny              CLASSIC_AT         0.620000
#                                   TRADES_v2          0.643333
# robust_deit_small_patch16_224     CLASSIC_AT         0.335333
#                                   TRADES_v2          0.489333
# vit_base_patch16_224.augreg_in1k  CLASSIC_AT         0.283333
#                                   TRADES_v2          0.321333
# vit_base_patch16_224.augreg_in21k CLASSIC_AT         0.199333
#                                   TRADES_v2          0.478667
# vit_base_patch16_224.dino         CLASSIC_AT         0.416000
#                                   TRADES_v2          0.493333
# vit_base_patch16_224.mae          CLASSIC_AT         0.101333
#                                   TRADES_v2          0.510667
# vit_base_patch16_224.orig_in21k   CLASSIC_AT         0.209333
#                                   TRADES_v2          0.551333
# vit_base_patch16_224.sam_in1k     CLASSIC_AT         0.326667
#                                   TRADES_v2          0.588000
# vit_base_patch16_224_miil.in21k   CLASSIC_AT         0.001333
#                                   TRADES_v2          0.132667

# %%
import pandas as pd
import numpy as np
import plotly.express as px


df_new_cleaned = df #.drop(columns=['Unnamed: 0'])
name =  'TRADES_v2' #
df_new_cleaned = df_new_cleaned[ df_new_cleaned.loss_function != name ]

# Assuming df_new_cleaned already exists and contains all necessary columns
# Group by backbone and loss function, compute the mean and standard deviation for clean and robust accuracy
aggregated_metrics = df_new_cleaned.groupby(['backbone', 'loss_function']).agg(
    Mean_Clean_Acc=('clean_acc', 'mean'),
    Std_Clean_Acc=('clean_acc', 'std'),
    Mean_Robust_Acc=('robust_acc', 'mean'),
    Std_Robust_Acc=('robust_acc', 'std')
).reset_index()

# Classify architectures into categories
aggregated_metrics['Architecture'] = aggregated_metrics['backbone'].apply(
    lambda name: 'ConvNext' if 'convnext' in name.lower() else ('ViT/DeiT' if 'deit' in name.lower() or 'vit' in name.lower() else 'Other')
)

# Assign marker shapes based on loss function
aggregated_metrics['Marker_Shape'] = aggregated_metrics['loss_function'].apply(
    lambda loss: 'circle' if loss == 'TRADES_v2' else ('square' if loss == 'CLASSIC_AT' else 'diamond')
)

# Identify Pareto front
x = aggregated_metrics['Mean_Clean_Acc']
y = aggregated_metrics['Mean_Robust_Acc']
is_pareto = np.array([
    not any((y[j] >= y[i] and x[j] >= x[i]) for j in range(len(x)) if i != j)
    for i in range(len(x))
])
pareto_points = aggregated_metrics[is_pareto]

# Add a mapping for loss functions to valid Plotly symbols
symbol_mapping = {
    'TRADES_v2': 'circle',
    'CLASSIC_AT': 'square'
}

# Update the scatter plot with proper legend entries for loss functions
fig = px.scatter(
    aggregated_metrics,
    x='Mean_Clean_Acc',
    y='Mean_Robust_Acc',
    color='Architecture',         # Color for architecture
    symbol='loss_function',       # Symbol for loss function
    # title='Backbone Performance: Clean vs. Robust Accuracy',
    labels={
        'Mean_Clean_Acc': 'Mean Clean Accuracy',
        'Mean_Robust_Acc': 'Mean Robust Accuracy',
        'loss_function': 'Loss Function'  # Custom label for legend
    },
    color_discrete_map={
        'ConvNext': '#1f77b4',  # Blue for ConvNext
        'ViT/DeiT': '#ff7f0e',  # Orange for ViT/DeiT
        'Other': '#2ca02c'      # Green for Other architectures
    },
    symbol_map=symbol_mapping    # Apply symbol mapping
)

# Add static backbone names as labels on the figure
for i, row in aggregated_metrics.iterrows():
    fig.add_annotation(
        x=row['Mean_Clean_Acc'] - 0.01,
        y=row['Mean_Robust_Acc'] + 0.01,  # Offset text slightly above the marker
        text=row['backbone'],
        showarrow=False,
        font=dict(size=10),
        align='center'
    )

# Add Pareto front markers with larger size and same shape/color as the original
for idx, d in enumerate(pareto_points.iterrows()):
    _, row = d
    fig.add_scatter(
        x=[row['Mean_Clean_Acc']],
        y=[row['Mean_Robust_Acc']],
        mode='markers',
        showlegend=False,  # Avoid duplicating legends
        marker=dict(
            size=13,  # Larger marker size
            symbol=symbol_mapping[row['loss_function']],  # Use the mapped symbol
            color=aggregated_metrics.loc[aggregated_metrics['backbone'] == row['backbone'], 'Architecture'].map({
                'ConvNext': '#1f77b4',  # Blue for ConvNext
                'ViT/DeiT': '#ff7f0e',  # Orange for ViT/DeiT
                'Other': '#2ca02c'     # Green for Other architectures
            }).values[0]  # Map the color dynamically
        ),
        name=f"Pareto"
    )


# Add a diagonal line (x = y)
fig.add_shape(
    type="line",
    x0=0, y0=0,  # Start of line
    x1=1, y1=1,  # End of line
    xref="paper", yref="paper",  # Use normalized coordinates (0 to 1 in plot space)
    line=dict(color="red", width=2, dash="dot")  # Line style
)

# Adjust layout for better visual clarity
fig.update_layout(
    legend_title=dict(text='Backbone and Loss Function'),
    width=600,
    height=600,
    font=dict(size=12),
    #title_font=dict(size=14),
    margin=dict(l=10, r=45, t=10, b=10),
    plot_bgcolor='rgba(0,0,0,0)',
    showlegend=False,
    xaxis=dict(showgrid=True, gridcolor='lightgrey', zeroline=False),
    yaxis=dict(showgrid=True, gridcolor='lightgrey', zeroline=False),
    yaxis_range=[0,0.7],
    xaxis_range=[0,0.85]
)


fig.update_layout(
    xaxis=dict(
        tickmode="array",
        tickvals=[0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85 ],
        ticktext=[0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85 ]
    ),
    yaxis=dict(
        tickmode="array",
        tickvals=[0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7 ],
        ticktext=[0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7 ]
    )
)

fig.show()
fig.write_image( "./figures/{}_{}.png".format(project_name,name) )

# %%
import comet_ml
import os

os.environ["COMET_API_KEY"] = "I5AiXfuD0TVuSz5UOtujrUM9i"

PROJECT_NAME="full-fine-tuning-5epochs-final1"
WORKSPACE_NAME="maxheuillet"

# Get all Experiemnts in workspace
api = comet_ml.API()

# all_experiments_in_workspace = api.get_experiments(WORKSPACE_NAME)
all_experiments_in_project = api.get_experiments(WORKSPACE_NAME, PROJECT_NAME)


backbones = [
  "convnext_tiny", "robust_convnext_tiny", "convnext_tiny.fb_in22k", 
  "deit_small_patch16_224.fb_in1k", "robust_deit_small_patch16_224",
  "convnext_base", "convnext_base.fb_in22k", "robust_convnext_base",
  "convnext_base.clip_laion2b", "convnext_base.clip_laion2b_augreg",
  "vit_base_patch16_224.augreg_in1k", "vit_base_patch16_224.augreg_in21k",
  "vit_base_patch16_224.dino", "vit_base_patch16_224.mae", 
  "vit_base_patch16_224.orig_in21k", "vit_base_patch16_224.sam_in1k",
  "vit_base_patch16_224_miil.in21k", ]

datas = [ "stanford_cars", "caltech101", "fgvc-aircraft-2013b", 
          "dtd", "flowers-102", "oxford-iiit-pet", ]

losses = [ "TRADES_v2", "CLASSIC_AT", ]

# 1) Build a dictionary
experiment_map = {}
for b in backbones:
    for d in datas:
        for l in losses:
            exp_name = f"{b}_{d}_{l}"
            experiment_map[exp_name] = (b, d, l)

# %%
import tqdm.notebook as tqdm
import pandas as pd

# data = all_experiments_in_project[0].get_metrics()
# import pandas as pd
# data = pd.DataFrame(data)
# set(data.metricName)

dataframe = []

for i in range(len(all_experiments_in_project)) :

    # 2) Suppose we have an experiment name to parse
    experiment_name = all_experiments_in_project[i].get_name()

    # 3) Look it up
    if experiment_name in experiment_map:
        backbone, dataset, loss = experiment_map[experiment_name]
        print("Backbone:", backbone)
        print("Dataset:", dataset)
        print("Loss:", loss)
    else:
        print("Experiment name not found in known combinations!")

    data = all_experiments_in_project[i].get_metrics()

    data = pd.DataFrame(data)

    df_filtered = data[ data.metricName == 'zero_adv_val' ]
    df_filtered = df_filtered.sort_values("step")
    zero_adv_val = df_filtered["metricValue"].tolist()
    zero_adv_val = [float(x) for x in zero_adv_val]

    df_filtered = data[ data.metricName == 'dormant_adv_val' ]
    df_filtered = df_filtered.sort_values("step")
    dormant_adv_val = df_filtered["metricValue"].tolist()
    dormant_adv_val = [float(x) for x in dormant_adv_val]

    df_filtered = data[ data.metricName == 'overactive_adv_val' ]
    df_filtered = df_filtered.sort_values("step")
    overactive_adv_val = df_filtered["metricValue"].tolist()
    overactive_adv_val = [float(x) for x in overactive_adv_val]


    df_filtered = data[ data.metricName == 'zero_adv_train' ]
    df_filtered = df_filtered.sort_values("step")
    zero_adv_train = df_filtered["metricValue"].tolist()
    zero_adv_train = [float(x) for x in zero_adv_train]

    df_filtered = data[ data.metricName == 'dormant_adv_train' ]
    df_filtered = df_filtered.sort_values("step")
    dormant_adv_train = df_filtered["metricValue"].tolist()
    dormant_adv_train = [float(x) for x in dormant_adv_train]

    df_filtered = data[ data.metricName == 'overactive_adv_train' ]
    df_filtered = df_filtered.sort_values("step")
    overactive_adv_train = df_filtered["metricValue"].tolist()
    overactive_adv_train = [float(x) for x in overactive_adv_train]

    df_filtered = data[ data.metricName == 'gradient_norm' ]
    df_filtered = df_filtered.sort_values("step")
    gradient_norm = df_filtered["metricValue"].tolist()
    gradient_norm = [float(x) for x in gradient_norm]

    if len(zero_adv_train) != 0:

        result = {'backbone':backbone, 'loss_function':loss, 'dataset':dataset,
                
            'zero_adv_train0':zero_adv_train[0], 
            'dormant_adv_train0':dormant_adv_train[0], 
            'overactive_adv_train0':overactive_adv_train[0], 
                
            'zero_adv_train5':zero_adv_train[-1], 
            'dormant_adv_train5':dormant_adv_train[-1], 
            'overactive_adv_train5':overactive_adv_train[-1],

            'zero_adv_val0':zero_adv_val[0], 
            'dormant_adv_val0':dormant_adv_val[0], 
            'overactive_adv_val0':overactive_adv_val[0], 
                
            'zero_adv_val5':zero_adv_val[-1], 
            'dormant_adv_val5':dormant_adv_val[-1], 
            'overactive_adv_val5':overactive_adv_val[-1], }
        
    else:

        pass

        # result = {'backbone':backbone, 'loss_function':loss, 'dataset':dataset,
                
        #         'zero_adv_train0':np.nan, 
        #         'dormant_adv_train0':np.nan, 
        #         'overactive_adv_train0':np.nan, 
                
        #         'zero_adv_train5':np.nan, 
        #         'dormant_adv_train5':np.nan, 
        #         'overactive_adv_train5':np.nan,  

        #         'zero_adv_val0':np.nan, 
        #         'dormant_adv_val0':np.nan, 
        #         'overactive_adv_val0':np.nan, 
                    
        #         'zero_adv_val5':np.nan, 
        #         'dormant_adv_val5':np.nan,  
        #         'overactive_adv_val5':np.nan,   }
    
    dataframe.append(result)

    # 'gradient_norm5':gradient_norm,
    # 'gradient_norm0':gradient_norm,
# Out:
# Backbone: robust_convnext_tiny
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_tiny.fb_in22k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: robust_deit_small_patch16_224
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_base
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: robust_convnext_base
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.mae
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.dino
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_tiny
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: robust_convnext_tiny
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: convnext_tiny.fb_in22k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: convnext_base
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: robust_convnext_base
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: convnext_base.fb_in22k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: robust_deit_small_patch16_224
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.dino
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: convnext_tiny
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.mae
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: robust_convnext_tiny
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: convnext_tiny.fb_in22k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: robust_deit_small_patch16_224
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: robust_convnext_base
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: convnext_base
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.mae
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.dino
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: convnext_tiny
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: robust_convnext_tiny
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: convnext_tiny.fb_in22k
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: convnext_base
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: convnext_base.fb_in22k
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: robust_deit_small_patch16_224
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: robust_convnext_base
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.dino
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.mae
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: convnext_tiny
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: robust_convnext_tiny
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: convnext_tiny.fb_in22k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: robust_deit_small_patch16_224
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: convnext_base
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: robust_convnext_base
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.dino
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.mae
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: convnext_tiny
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: robust_convnext_tiny
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_base
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_tiny.fb_in22k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_base.fb_in22k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: robust_deit_small_patch16_224
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: robust_convnext_base
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.dino
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.mae
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_tiny
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: robust_convnext_tiny
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_tiny.fb_in22k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: robust_deit_small_patch16_224
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_base
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: robust_convnext_base
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.dino
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.mae
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_tiny
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: robust_convnext_tiny
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: convnext_tiny.fb_in22k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: robust_deit_small_patch16_224
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: convnext_base
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: convnext_base.fb_in22k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: robust_convnext_base
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.dino
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.mae
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_tiny.fb_in22k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: robust_deit_small_patch16_224
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_base
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.dino
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_tiny.fb_in22k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: convnext_base
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: robust_deit_small_patch16_224
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.dino
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.mae
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: robust_convnext_base
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: robust_deit_small_patch16_224
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: robust_convnext_base
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: convnext_tiny.fb_in22k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: convnext_base
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: robust_convnext_tiny
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: convnext_tiny
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: fgvc-aircraft-2013b
# Loss: TRADES_v2
# Backbone: robust_convnext_base
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: robust_deit_small_patch16_224
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: convnext_tiny.fb_in22k
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: convnext_base
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.dino
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.mae
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: stanford_cars
# Loss: TRADES_v2
# Backbone: convnext_tiny
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: robust_convnext_tiny
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: robust_deit_small_patch16_224
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: convnext_tiny.fb_in22k
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: convnext_base
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: robust_convnext_base
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: convnext_base.fb_in22k
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.mae
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.dino
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: stanford_cars
# Loss: CLASSIC_AT
# Backbone: convnext_tiny
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: convnext_tiny.fb_in22k
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: robust_convnext_tiny
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: robust_deit_small_patch16_224
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: convnext_base
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: robust_convnext_base
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.mae
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.dino
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: convnext_tiny
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: convnext_tiny.fb_in22k
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: robust_convnext_tiny
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: robust_deit_small_patch16_224
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: convnext_base.fb_in22k
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: convnext_base
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: robust_convnext_base
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.mae
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.dino
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: caltech101
# Loss: CLASSIC_AT
# Backbone: robust_deit_small_patch16_224
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.dino
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: dtd
# Loss: CLASSIC_AT
# Backbone: robust_convnext_tiny
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_tiny
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_base.fb_in22k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_tiny.fb_in22k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_base
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: robust_convnext_base
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in1k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.mae
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.dino
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: convnext_base
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: flowers-102
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.mae
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: robust_deit_small_patch16_224
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: robust_convnext_tiny
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: flowers-102
# Loss: TRADES_v2
# Backbone: convnext_tiny.fb_in22k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_base
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: robust_convnext_base
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_tiny.fb_in22k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: robust_deit_small_patch16_224
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_base.fb_in22k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: robust_convnext_base
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.dino
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.mae
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: convnext_base
# Dataset: oxford-iiit-pet
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: caltech101
# Loss: TRADES_v2
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: robust_deit_small_patch16_224
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.dino
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: convnext_base.clip_laion2b_augreg
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: dtd
# Loss: TRADES_v2
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.mae
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.mae
# Dataset: fgvc-aircraft-2013b
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224_miil.in21k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.orig_in21k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.sam_in1k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.mae
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.augreg_in21k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: vit_base_patch16_224.dino
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: deit_small_patch16_224.fb_in1k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: robust_deit_small_patch16_224
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: robust_convnext_base
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: convnext_tiny.fb_in22k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: convnext_base.clip_laion2b
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: convnext_base.fb_in22k
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT
# Backbone: convnext_base
# Dataset: oxford-iiit-pet
# Loss: CLASSIC_AT

# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr

df2 = pd.DataFrame(dataframe)

df_merged = pd.merge(df, df2, on=["backbone", "loss_function", "dataset"], how="inner")

df_merged = df_merged.dropna(subset=["clean_acc", "robust_acc"])

df_merged.to_csv('results_corr.csv')

# Define a function to calculate correlation and p-values for a set of columns
def compute_correlations_with_pvalues(df, cols, target_vars):
    results = []
    
    for target in target_vars:  # clean_acc and robust_acc
        for col in cols:
            # Compute Pearson correlation and p-value

            # print( df[target], df[col] )
            pearson_corr, pearson_p = pearsonr(df[target], df[col])
            # Compute Spearman correlation and p-value
            spearman_corr, spearman_p = spearmanr(df[target], df[col])
            
            results.append({
                "target": target,
                "feature": col,
                "pearson_corr": pearson_corr,
                "pearson_pval": pearson_p,
                "spearman_corr": spearman_corr,
                "spearman_pval": spearman_p
            })
    
    return pd.DataFrame(results)

# Compute correlations and p-values for the specified columns
cols = [
    "zero_adv_train0",
    "dormant_adv_train0",
    "overactive_adv_train0",
    "zero_adv_train5",
    "dormant_adv_train5",
    "overactive_adv_train5",
    "zero_adv_val0",
    "dormant_adv_val0",
    "overactive_adv_val0",
]

target_vars = ["clean_acc", "robust_acc"]

# Correlation with p-values for the entire dataset
correlation_pvalues = compute_correlations_with_pvalues(df_merged, cols, target_vars)
# Set display option
pd.set_option("display.float_format", "{:.6f}".format)

correlation_pvalues
# Out:
#         target                feature  pearson_corr  pearson_pval  \
# 0    clean_acc        zero_adv_train0      0.052696      0.360652
# 1    clean_acc     dormant_adv_train0     -0.228202      0.000061
# 2    clean_acc  overactive_adv_train0     -0.295619      0.000000
# 3    clean_acc        zero_adv_train5     -0.055482      0.335792
# 4    clean_acc     dormant_adv_train5     -0.309784      0.000000
# 5    clean_acc  overactive_adv_train5     -0.295172      0.000000
# 6    clean_acc          zero_adv_val0     -0.108619      0.058960
# 7    clean_acc       dormant_adv_val0     -0.371039      0.000000
# 8    clean_acc    overactive_adv_val0     -0.311086      0.000000
# 9   robust_acc        zero_adv_train0      0.019196      0.739293
# 10  robust_acc     dormant_adv_train0     -0.130175      0.023438
# 11  robust_acc  overactive_adv_train0     -0.192276      0.000767
# 12  robust_acc        zero_adv_train5     -0.036112      0.531177
# 13  robust_acc     dormant_adv_train5     -0.237369      0.000030
# 14  robust_acc  overactive_adv_train5     -0.263039      0.000003
# 15  robust_acc          zero_adv_val0     -0.074803      0.194108
# 16  robust_acc       dormant_adv_val0     -0.252610      0.000009
# 17  robust_acc    overactive_adv_val0     -0.232708      0.000043
#
#     spearman_corr  spearman_pval
# 0       -0.015379       0.789768
# 1       -0.217585       0.000135
# 2       -0.264494       0.000003
# 3       -0.065050       0.258969
# 4       -0.261984       0.000004
# 5       -0.284226       0.000000
# 6       -0.062841       0.275527
# 7       -0.286809       0.000000
# 8       -0.275345       0.000001
# 9       -0.032260       0.575912
# 10      -0.135043       0.018686
# 11      -0.212739       0.000191
# 12      -0.085258       0.138701
# 13      -0.215689       0.000155
# 14      -0.278576       0.000001
# 15      -0.089915       0.118326
# 16      -0.200633       0.000442
# 17      -0.216997       0.000141

# %%
from scipy.stats import pearsonr, spearmanr
import pandas as pd

# Define the column groups for analysis
cols = [
    "zero_adv_train0",
    "dormant_adv_train0",
    "overactive_adv_train0",
    "zero_adv_train5",
    "dormant_adv_train5",
    "overactive_adv_train5",
    "zero_adv_val0",
    "dormant_adv_val0",
    "overactive_adv_val0",
]

# Define the backbone and loss groupings
group_backbones = {
    "convnext": ['convnext_tiny', 'robust_convnext_tiny', 'convnext_tiny.fb_in22k',
                 'convnext_base', 'convnext_base.fb_in22k', 'robust_convnext_base',
                 'convnext_base.clip_laion2b', 'convnext_base.clip_laion2b_augreg',  ],

    "vit": ['deit_small_patch16_224.fb_in1k', 'robust_deit_small_patch16_224',
            'vit_base_patch16_224.augreg_in1k', 'vit_base_patch16_224.augreg_in21k',
            'vit_base_patch16_224.dino', 'vit_base_patch16_224.mae', 'vit_base_patch16_224.orig_in21k',
            'vit_base_patch16_224.sam_in1k', 'vit_base_patch16_224_miil.in21k' ]
}

group_losses = {
    "trades_v2": ["TRADES_v2"],
    "classic_at": ["CLASSIC_AT"]
}

# Function to compute Pearson and Spearman correlations
def compute_group_correlations_and_summary(df, group_filter, target_cols):
    subgroup = df[group_filter]
    correlations = []
    summary_stats = []

    for target_col in target_cols:
        for acc_col in ["clean_acc", "robust_acc"]:
            # Drop NaNs for valid correlation computation
            valid_data = subgroup[[acc_col, target_col]].dropna()

            # Compute correlations if enough data
            if len(valid_data) > 1:
                # Pearson correlation
                pearson_corr, pearson_pval = pearsonr(valid_data[acc_col], valid_data[target_col])
                # Spearman correlation
                spearman_corr, spearman_pval = spearmanr(valid_data[acc_col], valid_data[target_col])
            else:
                pearson_corr = pearson_pval = spearman_corr = spearman_pval = float("nan")

            correlations.append({
                "target": acc_col,
                "feature": target_col,
                "pearson_corr": pearson_corr,
                "pearson_pval": pearson_pval,
                "spearman_corr": spearman_corr,
                "spearman_pval": spearman_pval
            })



    return pd.DataFrame(correlations)

# Create group filters
group_filters = {
    "convnext_trades_v2": (df_merged["backbone"].isin(group_backbones["convnext"])) & (df_merged["loss_function"].isin(group_losses["trades_v2"])),
    "convnext_classic_at": (df_merged["backbone"].isin(group_backbones["convnext"])) & (df_merged["loss_function"].isin(group_losses["classic_at"])),
    "vit_trades_v2": (df_merged["backbone"].isin(group_backbones["vit"])) & (df_merged["loss_function"].isin(group_losses["trades_v2"])),
    "vit_classic_at": (df_merged["backbone"].isin(group_backbones["vit"])) & (df_merged["loss_function"].isin(group_losses["classic_at"]))
}

# Compute correlations and summary statistics for each group
group_results = {}
for group_name, group_filter in group_filters.items():
    correlations = compute_group_correlations_and_summary(df_merged, group_filter, cols)
    group_results[group_name] =  correlations

# %%
group_results['convnext_trades_v2']
# Out:
#         target                feature  pearson_corr  pearson_pval  \
# 0    clean_acc        zero_adv_train0      0.278077      0.014337
# 1   robust_acc        zero_adv_train0      0.176726      0.124164
# 2    clean_acc     dormant_adv_train0     -0.173049      0.132313
# 3   robust_acc     dormant_adv_train0      0.002815      0.980615
# 4    clean_acc  overactive_adv_train0     -0.084981      0.462439
# 5   robust_acc  overactive_adv_train0      0.044153      0.702990
# 6    clean_acc        zero_adv_train5      0.366923      0.001029
# 7   robust_acc        zero_adv_train5      0.288635      0.010904
# 8    clean_acc     dormant_adv_train5      0.029108      0.801586
# 9   robust_acc     dormant_adv_train5      0.055022      0.634588
# 10   clean_acc  overactive_adv_train5     -0.120795      0.295344
# 11  robust_acc  overactive_adv_train5     -0.221571      0.052792
# 12   clean_acc          zero_adv_val0      0.314644      0.005320
# 13  robust_acc          zero_adv_val0      0.236322      0.038526
# 14   clean_acc       dormant_adv_val0     -0.110033      0.340771
# 15  robust_acc       dormant_adv_val0     -0.031073      0.788495
# 16   clean_acc    overactive_adv_val0     -0.089726      0.437728
# 17  robust_acc    overactive_adv_val0     -0.097591      0.398462
#
#     spearman_corr  spearman_pval
# 0        0.193150       0.092365
# 1        0.129389       0.262061
# 2        0.105029       0.363313
# 3        0.104542       0.365557
# 4       -0.043963       0.704207
# 5       -0.018587       0.872526
# 6        0.277327       0.014613
# 7        0.227680       0.046432
# 8        0.142149       0.217493
# 9        0.078625       0.496697
# 10      -0.147362       0.200918
# 11      -0.234525       0.040071
# 12       0.243921       0.032534
# 13       0.223003       0.051240
# 14       0.014358       0.901362
# 15       0.001309       0.990986
# 16      -0.050750       0.661146
# 17      -0.070942       0.539805

# %%
group_results['convnext_classic_at']
# Out:
#         target                feature  pearson_corr  pearson_pval  \
# 0    clean_acc        zero_adv_train0      0.023267      0.847277
# 1   robust_acc        zero_adv_train0     -0.049247      0.683386
# 2    clean_acc     dormant_adv_train0     -0.019678      0.870609
# 3   robust_acc     dormant_adv_train0      0.160410      0.181444
# 4    clean_acc  overactive_adv_train0     -0.136975      0.254675
# 5   robust_acc  overactive_adv_train0      0.036949      0.759670
# 6    clean_acc        zero_adv_train5      0.026053      0.829249
# 7   robust_acc        zero_adv_train5      0.012887      0.915053
# 8    clean_acc     dormant_adv_train5     -0.189723      0.113037
# 9   robust_acc     dormant_adv_train5     -0.161254      0.179128
# 10   clean_acc  overactive_adv_train5     -0.195810      0.101729
# 11  robust_acc  overactive_adv_train5     -0.362212      0.001909
# 12   clean_acc          zero_adv_val0      0.054786      0.649988
# 13  robust_acc          zero_adv_val0      0.001029      0.993205
# 14   clean_acc       dormant_adv_val0      0.039987      0.740577
# 15  robust_acc       dormant_adv_val0      0.097765      0.417307
# 16   clean_acc    overactive_adv_val0     -0.153082      0.202477
# 17  robust_acc    overactive_adv_val0     -0.211374      0.076810
#
#     spearman_corr  spearman_pval
# 0       -0.052414       0.664208
# 1       -0.056147       0.641879
# 2        0.056650       0.638895
# 3        0.165989       0.166530
# 4       -0.120374       0.317344
# 5        0.015041       0.900923
# 6       -0.071639       0.552718
# 7       -0.077860       0.518673
# 8       -0.119617       0.320420
# 9       -0.093539       0.437815
# 10      -0.249510       0.035869
# 11      -0.384642       0.000927
# 12       0.013410       0.911619
# 13      -0.065978       0.584605
# 14       0.084713       0.482428
# 15       0.179129       0.134993
# 16      -0.190383       0.111767
# 17      -0.165450       0.167931

# %%
group_results['vit_trades_v2']
# Out:
#         target                feature  pearson_corr  pearson_pval  \
# 0    clean_acc        zero_adv_train0     -0.021508      0.851733
# 1   robust_acc        zero_adv_train0      0.016650      0.884961
# 2    clean_acc     dormant_adv_train0     -0.122835      0.283990
# 3   robust_acc     dormant_adv_train0     -0.020020      0.861886
# 4    clean_acc  overactive_adv_train0     -0.364979      0.001018
# 5   robust_acc  overactive_adv_train0     -0.341184      0.002236
# 6    clean_acc        zero_adv_train5     -0.190859      0.094163
# 7   robust_acc        zero_adv_train5     -0.139728      0.222420
# 8    clean_acc     dormant_adv_train5     -0.387254      0.000461
# 9   robust_acc     dormant_adv_train5     -0.259408      0.021822
# 10   clean_acc  overactive_adv_train5     -0.292998      0.009233
# 11  robust_acc  overactive_adv_train5     -0.211323      0.063274
# 12   clean_acc          zero_adv_val0     -0.269246      0.017138
# 13  robust_acc          zero_adv_val0     -0.184484      0.105895
# 14   clean_acc       dormant_adv_val0     -0.531550      0.000001
# 15  robust_acc       dormant_adv_val0     -0.342199      0.002165
# 16   clean_acc    overactive_adv_val0     -0.311088      0.005567
# 17  robust_acc    overactive_adv_val0     -0.209917      0.065093
#
#     spearman_corr  spearman_pval
# 0       -0.156328       0.171694
# 1       -0.062502       0.586701
# 2       -0.221605       0.051190
# 3       -0.062945       0.584047
# 4       -0.370253       0.000848
# 5       -0.336946       0.002557
# 6       -0.240458       0.033955
# 7       -0.159868       0.162074
# 8       -0.364255       0.001044
# 9       -0.235139       0.038236
# 10      -0.291264       0.009676
# 11      -0.290912       0.009768
# 12      -0.231196       0.041692
# 13      -0.171067       0.134264
# 14      -0.507589       0.000002
# 15      -0.359434       0.001230
# 16      -0.283111       0.012018
# 17      -0.201338       0.077127

# %%
group_results['vit_classic_at']
# Out:
#         target                feature  pearson_corr  pearson_pval  \
# 0    clean_acc        zero_adv_train0     -0.073003      0.528062
# 1   robust_acc        zero_adv_train0     -0.061549      0.594893
# 2    clean_acc     dormant_adv_train0     -0.235505      0.039223
# 3   robust_acc     dormant_adv_train0     -0.187197      0.103054
# 4    clean_acc  overactive_adv_train0     -0.271727      0.016822
# 5   robust_acc  overactive_adv_train0     -0.248572      0.029267
# 6    clean_acc        zero_adv_train5     -0.341039      0.002404
# 7   robust_acc        zero_adv_train5     -0.280173      0.013589
# 8    clean_acc     dormant_adv_train5     -0.358839      0.001352
# 9   robust_acc     dormant_adv_train5     -0.312731      0.005621
# 10   clean_acc  overactive_adv_train5     -0.183563      0.110038
# 11  robust_acc  overactive_adv_train5     -0.134270      0.244333
# 12   clean_acc          zero_adv_val0     -0.311284      0.005858
# 13  robust_acc          zero_adv_val0     -0.247861      0.029748
# 14   clean_acc       dormant_adv_val0     -0.417202      0.000160
# 15  robust_acc       dormant_adv_val0     -0.362187      0.001209
# 16   clean_acc    overactive_adv_val0     -0.311217      0.005869
# 17  robust_acc    overactive_adv_val0     -0.234987      0.039670
#
#     spearman_corr  spearman_pval
# 0       -0.008945       0.938456
# 1       -0.017415       0.880505
# 2       -0.250567       0.027953
# 3       -0.205036       0.073644
# 4       -0.172416       0.133756
# 5       -0.212981       0.062923
# 6       -0.211748       0.064499
# 7       -0.223701       0.050498
# 8       -0.328837       0.003500
# 9       -0.295269       0.009134
# 10      -0.147318       0.201052
# 11      -0.146662       0.203088
# 12      -0.181953       0.113246
# 13      -0.204734       0.074080
# 14      -0.378876       0.000679
# 15      -0.330468       0.003332
# 16      -0.235834       0.038941
# 17      -0.214639       0.060855

# %%
import pandas as pd

# Function to compute summary statistics for clean_acc and robust_acc
def compute_summary_statistics(df, group_filter):
    subgroup = df[group_filter]
    summary_stats = []

    for acc_col in ["clean_acc", "robust_acc"]:
        # Compute statistics
        summary_stats.append({
            "metric": acc_col,
            "mean": subgroup[acc_col].mean(),
            "std_dev": subgroup[acc_col].std(),
            "min": subgroup[acc_col].min(),
            "max": subgroup[acc_col].max(),
            "count": subgroup[acc_col].count()
        })

    return pd.DataFrame(summary_stats)

# Compute statistics for each group
group_stats = {}
for group_name, group_filter in group_filters.items():
    stats = compute_summary_statistics(df_merged, group_filter)
    group_stats[group_name] = stats

# Display results
for group_name, stats in group_stats.items():
    print(f"\nGroup: {group_name}")
    print(stats)
# Out:
# Group: convnext_trades_v2
#        metric     mean  std_dev      min      max  count
# 0   clean_acc 0.662035 0.253751 0.075333 0.982000     77
# 1  robust_acc 0.394740 0.259645 0.000667 0.931333     77
#
# Group: convnext_classic_at
#        metric     mean  std_dev      min      max  count
# 0   clean_acc 0.620166 0.288749 0.063333 0.983333     71
# 1  robust_acc 0.387489 0.291329 0.000000 0.929333     71
#
# Group: vit_trades_v2
#        metric     mean  std_dev      min      max  count
# 0   clean_acc 0.586718 0.294651 0.010000 0.960000     78
# 1  robust_acc 0.306639 0.267958 0.002667 0.890000     78
#
# Group: vit_classic_at
#        metric     mean  std_dev      min      max  count
# 0   clean_acc 0.476320 0.310968 0.006667 0.962000     77
# 1  robust_acc 0.313797 0.273216 0.000000 0.904667     77

# %%
import plotly.graph_objects as go

# List of data
data = [
    {'lr1': 0.010516039540919314,
     'lr2': 0.010363459483491242,
     'weight_decay1': 0.004921507397015504,
     'weight_decay2': 0.0007016152732955533,
     'loss_list': [4.694242956283245]},
    {'lr1': 0.0002647406823793355,
     'lr2': 1.273134447725369e-05,
     'weight_decay1': 4.3810753037654765e-06,
     'weight_decay2': 0.0009606136882729996,
     'loss_list': [4.690766289893617]},
    {'lr1': 0.009579387106832937,
     'lr2': 0.0047526033939376995,
     'weight_decay1': 1.1473032680323029e-05,
     'weight_decay2': 1.842210858018915e-06,
     'loss_list': [4.5678955078125, 4.570035634142287, 4.552429458942819, 5.531184030086436]},
    {'lr1': 2.5664790016446088e-05,
     'lr2': 0.0004531311844091792,
     'weight_decay1': 0.0005992397731141753,
     'weight_decay2': 4.536459919009385e-05,
     'loss_list': [4.573969414893617, 4.564487928025266, 4.242278403424202, 4.178591464428192]}
]

# Create a figure
fig = go.Figure()

# Add traces for each loss_list
for idx, entry in enumerate(data):
    fig.add_trace(go.Scatter(
        y=entry['loss_list'],
        mode='lines+markers',
        name=f'Loss List {idx + 1}'
    ))

# Update layout
fig.update_layout(
    title="Loss List for Each Configuration",
    xaxis_title="Index within Loss List",
    yaxis_title="Loss",
    legend_title="Configuration",
    template="plotly"
)

# Display the plot
fig.show()
