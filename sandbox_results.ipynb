# %%
import comet_ml

import os
os.environ["COMET_API_KEY"] = "I5AiXfuD0TVuSz5UOtujrUM9i"

PROJECT_NAME="robust-training"
WORKSPACE_NAME="maxheuillet"

# Get all Experiemnts in workspace
api = comet_ml.API()

# all_experiments_in_workspace = api.get_experiments(WORKSPACE_NAME)
all_experiments_in_project = api.get_experiments(WORKSPACE_NAME, PROJECT_NAME)

# %%
# Convert the experiment summary to an APIExperiment using the experiment key
from tqdm.notebook import tqdm

data = {}
for i in tqdm( range(len(all_experiments_in_project)) ):
    summary = all_experiments_in_project[i].get_parameters_summary()

    d = {}
    for e in summary:
        if e['name'] in ['run_id', 'arch','aug','sched', 'batch_size','init_lr','sched','pruning_strategy','pruning_ratio','loss_function','iterations']:
            if e['name'] == 'run_id':
                id = e['valueMax']
            else:
                d[e['name']] = e['valueMax']
        
    if id not in data.keys():
        try:
            adv_acc  = all_experiments_in_project[i].get_metrics('final_robust_accuracy')[0]
            d[ 'adv_acc' ] = adv_acc['metricValue']
            nat_acc = all_experiments_in_project[i].get_metrics('final_clean_accuracy')[0]
            d[ 'nat_acc' ] = nat_acc['metricValue']
        except:
            d[ 'adv_acc' ] = None
            d[ 'nat_acc' ] = None

        data[id] = d

data
# Out:
#   0%|          | 0/1763 [00:00<?, ?it/s]
# {'51344299': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.2617',
#   'nat_acc': '0.7769'},
#  '51344302': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.2311',
#   'nat_acc': '0.7605'},
#  '51344301': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.2757',
#   'nat_acc': '0.7996'},
#  '51344298': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': '0.2518',
#   'nat_acc': '0.7643'},
#  '51344300': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.1635',
#   'nat_acc': '0.7116'},
#  '51344303': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.2176',
#   'nat_acc': '0.7573'},
#  '51344304': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.269',
#   'nat_acc': '0.8113'},
#  '51344305': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51344306': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.2509',
#   'nat_acc': '0.7989'},
#  '51344307': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.2852',
#   'nat_acc': '0.8223'},
#  '51344308': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.296',
#   'nat_acc': '0.8221'},
#  '51344309': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.2545',
#   'nat_acc': '0.791'},
#  '51344310': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.1658',
#   'nat_acc': '0.7437'},
#  '51344311': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.2923',
#   'nat_acc': '0.8085'},
#  '51344312': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': '0.2778',
#   'nat_acc': '0.7672'},
#  '51344314': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.261',
#   'nat_acc': '0.818'},
#  '51344313': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.2132',
#   'nat_acc': '0.7862'},
#  '51344315': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.3024',
#   'nat_acc': '0.7967'},
#  '51344316': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.2832',
#   'nat_acc': '0.8521'},
#  '51344317': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.272',
#   'nat_acc': '0.8425'},
#  '51344318': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.2286',
#   'nat_acc': '0.8343'},
#  '51344565': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': '0.3249',
#   'nat_acc': '0.7892'},
#  '51344567': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3755',
#   'nat_acc': '0.8057'},
#  '51344566': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': '0.292',
#   'nat_acc': '0.7424'},
#  '51344568': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3003',
#   'nat_acc': '0.7804'},
#  '51344569': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.3849',
#   'nat_acc': '0.8137'},
#  '51344570': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.3038',
#   'nat_acc': '0.7859'},
#  '51344571': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.3703',
#   'nat_acc': '0.8118'},
#  '51344572': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.3038',
#   'nat_acc': '0.7881'},
#  '51344573': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.293',
#   'nat_acc': '0.7751'},
#  '51344574': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.2067',
#   'nat_acc': '0.6455'},
#  '51344575': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.2925',
#   'nat_acc': '0.8077'},
#  '51344576': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.2029',
#   'nat_acc': '0.6809'},
#  '51344577': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.2867',
#   'nat_acc': '0.7925'},
#  '51344578': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.2131',
#   'nat_acc': '0.6889'},
#  '51344579': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51344580': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51344581': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3991',
#   'nat_acc': '0.8262'},
#  '51344582': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3112',
#   'nat_acc': '0.7707'},
#  '51344583': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.3817',
#   'nat_acc': '0.8225'},
#  '51344584': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.3322',
#   'nat_acc': '0.7941'},
#  '51344585': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.3948',
#   'nat_acc': '0.8285'},
#  '51344586': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.3289',
#   'nat_acc': '0.7981'},
#  '51344587': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.3605',
#   'nat_acc': '0.8324'},
#  '51344588': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.2811',
#   'nat_acc': '0.7393'},
#  '51344589': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.3558',
#   'nat_acc': '0.8152'},
#  '51344590': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.2908',
#   'nat_acc': '0.7544'},
#  '51344591': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3581',
#   'nat_acc': '0.8172'},
#  '51344592': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.2884',
#   'nat_acc': '0.7798'},
#  '51344593': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51344594': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51344595': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3849',
#   'nat_acc': '0.8131'},
#  '51344596': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3055',
#   'nat_acc': '0.7794'},
#  '51344597': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.3922',
#   'nat_acc': '0.8055'},
#  '51344598': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.3219',
#   'nat_acc': '0.8023'},
#  '51344599': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.3756',
#   'nat_acc': '0.8254'},
#  '51344600': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.3189',
#   'nat_acc': '0.775'},
#  '51344601': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.3164',
#   'nat_acc': '0.7949'},
#  '51344602': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.247',
#   'nat_acc': '0.6993'},
#  '51344603': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.3304',
#   'nat_acc': '0.8115'},
#  '51344604': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.2551',
#   'nat_acc': '0.7366'},
#  '51344605': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3148',
#   'nat_acc': '0.8059'},
#  '51348417': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': '0.2276',
#   'nat_acc': '0.8183'},
#  '51344606': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.2476',
#   'nat_acc': '0.7464'},
#  '51348418': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': '0.3721',
#   'nat_acc': '0.8132'},
#  '51348419': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': '0.3247',
#   'nat_acc': '0.7785'},
#  '51348420': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.2143',
#   'nat_acc': '0.7312'},
#  '51348421': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.3938',
#   'nat_acc': '0.8116'},
#  '51348422': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.3316',
#   'nat_acc': '0.7758'},
#  '51348423': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': '0.2882',
#   'nat_acc': '0.8017'},
#  '51348425': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': '0.3341',
#   'nat_acc': '0.7786'},
#  '51348426': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': '0.3015',
#   'nat_acc': '0.8085'},
#  '51348424': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': '0.3862',
#   'nat_acc': '0.8155'},
#  '51348427': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': '0.4004',
#   'nat_acc': '0.8345'},
#  '51348428': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': '0.3287',
#   'nat_acc': '0.7695'},
#  '51348429': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': '0.2852',
#   'nat_acc': '0.8121'},
#  '51348430': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': '0.3736',
#   'nat_acc': '0.8257'},
#  '51348431': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': '0.2653',
#   'nat_acc': '0.7602'},
#  '51348432': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': '0.2715',
#   'nat_acc': '0.8044'},
#  '51348433': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': '0.3715',
#   'nat_acc': '0.8294'},
#  '51348434': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': '0.2804',
#   'nat_acc': '0.7685'},
#  '51348435': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.2826',
#   'nat_acc': '0.8167'},
#  '51348436': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.3583',
#   'nat_acc': '0.8305'},
#  '51348437': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.285',
#   'nat_acc': '0.7877'},
#  '51348438': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51348439': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51348440': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51348441': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.2518',
#   'nat_acc': '0.8232'},
#  '51348442': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.3753',
#   'nat_acc': '0.839'},
#  '51348443': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.3417',
#   'nat_acc': '0.7976'},
#  '51348444': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': '0.2875',
#   'nat_acc': '0.8334'},
#  '51348445': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': '0.3743',
#   'nat_acc': '0.8318'},
#  '51348446': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': '0.3553',
#   'nat_acc': '0.7972'},
#  '51348447': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': '0.2704',
#   'nat_acc': '0.8236'},
#  '51348448': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': '0.3923',
#   'nat_acc': '0.8349'},
#  '51348449': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': '0.3424',
#   'nat_acc': '0.8016'},
#  '51348450': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': '0.2217',
#   'nat_acc': '0.7968'},
#  '51348451': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': '0.3745',
#   'nat_acc': '0.8279'},
#  '51348452': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': '0.326',
#   'nat_acc': '0.786'},
#  '51348453': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': '0.3051',
#   'nat_acc': '0.8183'},
#  '51348454': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': '0.3855',
#   'nat_acc': '0.8361'},
#  '51348455': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': '0.3234',
#   'nat_acc': '0.8029'},
#  '51348456': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.2957',
#   'nat_acc': '0.8353'},
#  '51348457': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.3712',
#   'nat_acc': '0.8289'},
#  '51348458': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.3374',
#   'nat_acc': '0.7902'},
#  '51348459': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': '0.2641',
#   'nat_acc': '0.8389'},
#  '51348462': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.2609',
#   'nat_acc': '0.8122'},
#  '51348460': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51348465': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': '0.2903',
#   'nat_acc': '0.8455'},
#  '51348464': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.3392',
#   'nat_acc': '0.7772'},
#  '51348463': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.378',
#   'nat_acc': '0.8375'},
#  '51348461': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51348466': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': '0.3941',
#   'nat_acc': '0.8187'},
#  '51348467': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': '0.3547',
#   'nat_acc': '0.7885'},
#  '51348468': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': '0.2391',
#   'nat_acc': '0.8118'},
#  '51348469': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': '0.38',
#   'nat_acc': '0.8308'},
#  '51348470': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': '0.3402',
#   'nat_acc': '0.7942'},
#  '51348471': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': '0.2922',
#   'nat_acc': '0.8261'},
#  '51348472': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': '0.3687',
#   'nat_acc': '0.8302'},
#  '51348474': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': '0.2557',
#   'nat_acc': '0.8201'},
#  '51348473': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': '0.304',
#   'nat_acc': '0.7764'},
#  '51348475': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': '0.3796',
#   'nat_acc': '0.8092'},
#  '51348476': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': '0.3002',
#   'nat_acc': '0.7973'},
#  '51348477': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.2552',
#   'nat_acc': '0.7803'},
#  '51348478': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.3473',
#   'nat_acc': '0.8298'},
#  '51348479': {'arch': 'resnet50',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': '0.3027',
#   'nat_acc': '0.7903'},
#  '51357292': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357296': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357295': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357297': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357293': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357291': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357294': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357301': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357298': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357300': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357299': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357302': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357303': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357304': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357308': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357305': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357307': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357306': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357310': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357309': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357311': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357314': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357313': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357312': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357317': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357315': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357318': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357316': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357327': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357329': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357331': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357330': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357322': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357332': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357333': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357334': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357320': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357321': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357335': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357328': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357325': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357326': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357337': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357336': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357340': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357338': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357339': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357341': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357342': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357343': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357344': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357345': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357346': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357347': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'nosched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51357348': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '1042',
# ...
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.2979',
#   'nat_acc': '0.7981'},
#  '51362569': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362573': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3241',
#   'nat_acc': '0.8443'},
#  '51362566': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.1691',
#   'nat_acc': '0.7346'},
#  '51362572': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.2778',
#   'nat_acc': '0.7853'},
#  '51362574': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3745',
#   'nat_acc': '0.8141'},
#  '51362570': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362565': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.3079',
#   'nat_acc': '0.8189'},
#  '51362567': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3413',
#   'nat_acc': '0.819'},
#  '51362583': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.3545',
#   'nat_acc': '0.8026'},
#  '51362576': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.3449',
#   'nat_acc': '0.847'},
#  '51362578': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.2692',
#   'nat_acc': '0.819'},
#  '51362581': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.2408',
#   'nat_acc': '0.778'},
#  '51362580': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.3699',
#   'nat_acc': '0.8251'},
#  '51362577': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.3878',
#   'nat_acc': '0.8181'},
#  '51362575': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.2492',
#   'nat_acc': '0.8052'},
#  '51362582': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.3371',
#   'nat_acc': '0.8402'},
#  '51362579': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.3417',
#   'nat_acc': '0.8327'},
#  '51362585': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.3038',
#   'nat_acc': '0.836'},
#  '51362586': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.3624',
#   'nat_acc': '0.8193'},
#  '51362584': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.2232',
#   'nat_acc': '0.788'},
#  '51362587': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.246',
#   'nat_acc': '0.7977'},
#  '51362588': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3107',
#   'nat_acc': '0.8297'},
#  '51362589': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.3',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': '0.3535',
#   'nat_acc': '0.8392'},
#  '51362592': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362590': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': '0.2436',
#   'nat_acc': '0.7497'},
#  '51362591': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': '0.3177',
#   'nat_acc': '0.8423'},
#  '51362593': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362594': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362595': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362597': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.3667',
#   'nat_acc': '0.8178'},
#  '51362598': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.3915',
#   'nat_acc': '0.8193'},
#  '51362600': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.3413',
#   'nat_acc': '0.8322'},
#  '51362604': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.3351',
#   'nat_acc': '0.8237'},
#  '51362602': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.2169',
#   'nat_acc': '0.7912'},
#  '51362603': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': '0.3373',
#   'nat_acc': '0.8439'},
#  '51362601': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362605': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': '0.2036',
#   'nat_acc': '0.7548'},
#  '51362606': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362596': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': '0.2245',
#   'nat_acc': '0.7836'},
#  '51362599': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': '0.2104',
#   'nat_acc': '0.7994'},
#  '51362607': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v1',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362608': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362612': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362610': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362609': {'arch': 'resnet50',
#   'aug': 'aug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.5',
#   'pruning_strategy': 'score_v2',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362613': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362616': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362617': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362614': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v3',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362618': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362615': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'decay_based_v2',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362619': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362620': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'TS_pruning',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362621': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362622': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362623': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.001',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'random',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362624': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.2',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None},
#  '51362625': {'arch': 'resnet50',
#   'aug': 'noaug',
#   'batch_size': '128',
#   'init_lr': '0.01',
#   'iterations': '60',
#   'loss_function': 'TRADES_v2',
#   'pruning_ratio': '0.7',
#   'pruning_strategy': 'uncertainty',
#   'sched': 'sched',
#   'adv_acc': None,
#   'nat_acc': None}}

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# Assuming 'data' is defined
df = pd.DataFrame(data).T
df['adv_acc'] = pd.to_numeric(df['adv_acc'], errors='coerce')
df['nat_acc'] = pd.to_numeric(df['nat_acc'], errors='coerce')
df['aug'] = df['aug'].fillna('aug')

pruning_ratio = '0.3'
batch_size = '128'
aug = 'aug'
sched = 'sched'
init_lr = '0.01'
name = pruning_ratio+'_'+batch_size+'_'+aug+'_'+sched+'_'+init_lr

# Apply filtering
df = df[(df['pruning_ratio'] == pruning_ratio) & 
        (df['batch_size'] == batch_size) &
        (df['aug'] == aug) &
        (df['sched'] == sched) &
        (df['init_lr'] == init_lr)   ]

# Sort the dataframe by natural and adversarial accuracy
sorted_df = df.sort_values(by=['nat_acc', 'adv_acc'], ascending=[False, False])

# Identify the Pareto frontier
pareto_front = []
current_best = -np.inf

for index, row in sorted_df.iterrows():
    if row['adv_acc'] > current_best:
        pareto_front.append((row['nat_acc'], row['adv_acc'], row['pruning_strategy']))
        current_best = row['adv_acc']

pareto_front = np.array(pareto_front)

# Color map for different pruning strategies
color_map = {
    'random': 'blue',
    'TS_pruning': 'green', 
    'score_v1': 'orange',
    'score_v2': 'purple',
    'decay_based_v2': 'brown',
    'decay_based_v3': 'magenta',
    'uncertainty': 'red'
}

# Step 3: Plot using plotly
fig = go.Figure()

# Add all methods as separate scatter points, one for each pruning_strategy
for strategy, color in color_map.items():
    df_subset = df[df['pruning_strategy'] == strategy]
    fig.add_trace(go.Scatter(
        x=df_subset['nat_acc'],
        y=df_subset['adv_acc'],
        mode='markers',
        marker=dict(color=color, size=10),
        name=strategy,
        text=df_subset['pruning_strategy'],  # Hover text for each point
        showlegend=True
    ))

# Add Pareto frontier as a red line but retain original marker colors
fig.add_trace(go.Scatter(
    x=pareto_front[:, 0].astype(float),
    y=pareto_front[:, 1].astype(float),
    mode='lines+markers',
    line=dict(color='black', width=2),
    marker=dict(
        color=[color_map[strategy] for strategy in pareto_front[:, 2]],
        size=10
    ),
    name='Pareto Frontier',
    text=pareto_front[:, 2],  # Hover text for Pareto points
    showlegend=False
))

# Update layout with legend inside the figure and square aspect ratio
fig.update_layout(
    title='Frontier Analysis: ' + name,
    xaxis_title='Clean Accuracy',
    yaxis_title='Robust Accuracy',
    xaxis=dict(range=[0.7, 0.9]),
    yaxis=dict(range=[0.25, 0.5]),
    margin=dict(l=0, r=0, t=35, b=0),  # Margins set to 0
    width=400,  # Set figure width to 3 inches (300px at 96dpi)
    height=400,  # Set figure height to 3 inches (300px at 96dpi)
    showlegend=True,
    legend=dict(
        x=0.02,  # Position the legend inside the figure
        y=0.98,
        traceorder="normal",
        bgcolor="rgba(255, 255, 255, 1)",  # Semi-transparent background
        bordercolor="Black",
        borderwidth=1
    )
)

# Display the plot
fig.show()

# Save the figure
fig.write_image("./figures/pareto_front_{}.png".format(name))

# %%
df
# Out:
#               arch batch_size init_lr iterations loss_function pruning_ratio  \
# 51357313  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357316  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357331  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357322  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357328  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357325  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357319  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357553  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357560  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357557  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357563  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357566  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357569  resnet50       1042    0.01         60     TRADES_v2           0.3
# 51357572  resnet50       1042    0.01         60     TRADES_v2           0.3
#
#          pruning_strategy    sched  adv_acc  nat_acc    aug
# 51357313   decay_based_v3  nosched      NaN      NaN  noaug
# 51357316   decay_based_v2  nosched      NaN      NaN  noaug
# 51357331         score_v2  nosched      NaN      NaN  noaug
# 51357322           random  nosched      NaN      NaN  noaug
# 51357328         score_v1  nosched      NaN      NaN  noaug
# 51357325      uncertainty  nosched      NaN      NaN  noaug
# 51357319       TS_pruning  nosched      NaN      NaN  noaug
# 51357553   decay_based_v3  nosched      NaN      NaN  noaug
# 51357560       TS_pruning  nosched   0.4239   0.8349  noaug
# 51357557   decay_based_v2  nosched   0.4072   0.8389  noaug
# 51357563           random  nosched   0.3846   0.8464  noaug
# 51357566      uncertainty  nosched   0.4209   0.8326  noaug
# 51357569         score_v1  nosched   0.3766   0.8552  noaug
# 51357572         score_v2  nosched   0.4129   0.8393  noaug

# %%
import plotly.graph_objects as go

metric = 'final_PGD_accuracy_mean' #'final_clean_accuracy_mean'
# Convert the learning rate column to string to match keys in the lr_styles dictionary
data['learning_rate'] = data['learning_rate'].astype(str)

# Update the strategy_colors dictionary to include all unique strategies from the data
strategy_colors = {'random': 'red', 'uncertainty': 'blue'}

# Define line styles for learning rates
lr_styles = {'0.01': 'dot', '0.001': 'solid',  '0.0001': 'dashdot', '1e-05': 'longdash'}

# Reinitialize the figure with increased marker size and improved legend
fig = go.Figure()

# Add traces for each combination of sched and active_strategy
for sched in data['scheduler'].unique():
    for active_strategy in data['active_strategy'].unique():
        subset = data[(data['scheduler'] == sched) & (data['active_strategy'] == active_strategy)]
        for lr in subset['learning_rate'].unique():
            subsubset = subset[subset['learning_rate'] == lr]
            fig.add_trace(go.Scatter(
                x=subsubset['size'],
                y=subsubset[metric], 
                mode='lines+markers',
                name=f'{active_strategy}, {sched}, {lr}',
                line=dict(color=strategy_colors[active_strategy], dash=lr_styles[lr]),
                marker=dict(symbol='circle' if sched == 'nosched' else 'square', size=10)
            ))

# Update layout for better legend visibility
fig.update_layout(
    margin=dict(l=0, r=0, t=50, b=0),
    title='{} by Size and Strategy'.format(metric),
    xaxis_title='Size',
    yaxis_title=metric,
    legend_title='Strategy Details',
    legend=dict(
        orientation="v",
        yanchor="top",
        y=1,
        xanchor="right",
        x=1.3,
        title_font=dict(size=15),
        font=dict(size=15)
    )
)

# fig.write_image("./figures/results_{}_{}_{}_{}_{}.pdf".format(metric, data_name, model, n_rounds, nb_epochs) )

# %%
import plotly.graph_objects as go
import pandas as pd

# Load and prepare the data
new_data = pd.read_csv('results/means.csv', skiprows=2)
new_data.columns = ['active_strategy', 'size', 'final_clean_accuracy',
                    'final_clean_accuracy_std', 'final_PGD_accuracy', 'final_PGD_accuracy_std']
new_data['size'] = new_data['size'].astype(int)

for performance in ['PGD_accuracy', 'clean_accuracy' ]:
# performance = 'final_PGD_accuracy' 
# # performance = 'final_clean_accuracy'
    fig = go.Figure()

    # fig.add_trace(go.Scatter(x=[0, 50000], y=[ init_means_stds['init_'+performance]['mean'][0], init_means_stds['init_'+performance]['mean'][0] ],
    #         mode='lines', line=dict(color='rgba({},{},{},1)'.format(0,0,204), width=2, dash='dot'),
    #                     name='Init Accuracy', showlegend=True))


    performance = 'final_'+performance
    performance_std = performance + '_std'  # Corresponding standard deviation column

    strategies = {
        # 'attack_uncertainty': {'color': [204, 0, 204], 'label': 'attack-uncertainty'},  # Red
        # 'full': {'color': [0, 0, 0], 'label': 'full'},  # Red
        'uncertainty': {'color': [255, 161, 90], 'label':'uncertainty'},                    # Yellow
        'random': {'color': [25, 211, 243], 'label':'random'},                    # Cyan
        # 'entropy': {'color': [255, 102, 146], 'label':'entropy'},                  # Magenta
        # 'attack': {'color': [182, 232, 128], 'label':'attack'},                   # Orange
        # 'margin': {'color': [254, 203, 82], 'label':'margin'},
    }


    z_value = 2.576
    n = 5

    # Add a line for each strategy
    for strategy, v in strategies.items():
        r,g,b = v['color']
        c = 'rgba({},{},{},1)'.format(r,g,b)

        # Add a horizontal line for the 'full' strategy
        if strategy == 'full':
            pass
        #     full_data = new_data[new_data['active_strategy'] == 'full']
        #     # Calculate the mean PGD accuracy for the 'full' strategy
        #     full_mean_accuracy = full_data[performance].mean()
        #     fig.add_trace(go.Scatter(x=[min(new_data['size']), max(new_data['size'])], y=[full_mean_accuracy, full_mean_accuracy],
        #                             mode='lines', line=dict(color=c, width=2, dash='dash'),
        #                             name='Full Dataset Average', showlegend=True))
            
        #     strategy_data = new_data[new_data['active_strategy'] == strategy]
        #     fig.add_trace(go.Scatter( x=strategy_data['size'],  y=strategy_data[performance],  mode='lines+markers',
        #                     name=strategy, line=dict(color=c  ) ,
        #                     error_y=dict(
        #                     type='data',  symmetric=False,  
        #                     array=z_value * strategy_data[performance_std] / n,  
        #                     arrayminus=z_value * strategy_data[performance_std] / n   ), showlegend=False
        #                         ))

            
        else:
            strategy_data = new_data[new_data['active_strategy'] == strategy]
            fig.add_trace(go.Scatter(x=strategy_data['size'], y=strategy_data[performance], line=dict(color=c),
                                    error_y=dict(
                                        type='data',  symmetric=False,  
                                        array=z_value * strategy_data[performance_std] / n,  
                                        arrayminus=z_value * strategy_data[performance_std] / n   ),
                                    mode='lines+markers', name=strategy))


    title_str = 'Robust accuracy' if performance=='final_PGD_accuracy' else 'Clean Accuracy'

    # Update layout and display the plot
    fig.update_layout(
        width=600,  # Adjusted for two subplots
        height=400,
        plot_bgcolor='white',
        paper_bgcolor='white',
        margin=dict(l=0, r=0, t=50, b=0),
        # title="Box Plot of Datasets by Cases and Columns",
        title=title_str,
        xaxis_title='Size (% of training observations)',
        yaxis_title=title_str,
        legend_title='Data Selection Strategy',
        # yaxis_range=[min(new_data[performance]) - 2, max(new_data[performance]) + 2],
        showlegend=True,
        xaxis=dict(
            # type='log',
            showgrid=True,        # Enable the grid
            gridcolor='lightgray' # Set grid line color
        ),
        yaxis=dict(
            showgrid=True,        # Enable the grid
            gridcolor='lightgray', # Set grid line color
            #range=[75,94] if 'clean' in performance else [45,65]
        )
        )

    # Display the figure
    fig.show()
    # fig.write_image("./figures/results_{}_{}_{}_{}_{}.pdf".format(performance, data, model, n_rounds, nb_epochs) )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 6
#       4 # Load and prepare the data
#       5 new_data = pd.read_csv('results/means.csv', skiprows=2)
# ----> 6 new_data.columns = ['active_strategy', 'size', 'final_clean_accuracy',
#       7                     'final_clean_accuracy_std', 'final_PGD_accuracy', 'final_PGD_accuracy_std']
#       8 new_data['size'] = new_data['size'].astype(int)
#      10 for performance in ['PGD_accuracy', 'clean_accuracy' ]:
#      11 # performance = 'final_PGD_accuracy'
#      12 # # performance = 'final_clean_accuracy'
#
# File ~/Desktop/robust_training/.venv/lib/python3.8/site-packages/pandas/core/generic.py:6002, in NDFrame.__setattr__(self, name, value)
#    6000 try:
#    6001     object.__getattribute__(self, name)
# -> 6002     return object.__setattr__(self, name, value)
#    6003 except AttributeError:
#    6004     pass
#
# File ~/Desktop/robust_training/.venv/lib/python3.8/site-packages/pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/Desktop/robust_training/.venv/lib/python3.8/site-packages/pandas/core/generic.py:730, in NDFrame._set_axis(self, axis, labels)
#     725 """
#     726 This is called from the cython code when we set the `index` attribute
#     727 directly, e.g. `series.index = [1, 2, 3]`.
#     728 """
#     729 labels = ensure_index(labels)
# --> 730 self._mgr.set_axis(axis, labels)
#     731 self._clear_item_cache()
#
# File ~/Desktop/robust_training/.venv/lib/python3.8/site-packages/pandas/core/internals/managers.py:225, in BaseBlockManager.set_axis(self, axis, new_labels)
#     223 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     224     # Caller is responsible for ensuring we have an Index object.
# --> 225     self._validate_set_axis(axis, new_labels)
#     226     self.axes[axis] = new_labels
#
# File ~/Desktop/robust_training/.venv/lib/python3.8/site-packages/pandas/core/internals/base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 7 elements, new values have 6 elements
